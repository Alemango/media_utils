# %%
# -*- coding: utf-8 -*-
import pandas as pd
import psycopg2
from io import StringIO
import numpy as np

def load_data_from_csv(csv_file_path, table_name, db_params, separator, 
                       date_columns=[], timestamp_columns=[], numeric_columns_to_clean=[], 
                       encoding='latin-1'):
    """
    Carga datos desde un archivo CSV a PostgreSQL de forma robusta.
    Permite especificar el separador, la codificación y las columnas a limpiar.

    Args:
        csv_file_path (str): Ruta al archivo CSV.
        table_name (str): Nombre de la tabla de destino en PostgreSQL.
        db_params (dict): Parámetros de conexión a la base de datos.
        separator (str): El carácter que separa las columnas en el CSV.
        date_columns (list): Columnas que son solo fecha (DATE).
        timestamp_columns (list): Columnas con fecha y hora (TIMESTAMP).
        numeric_columns_to_clean (list): Columnas numéricas que pueden tener espacios (ej. "300 000").
        encoding (str): La codificación del archivo de texto.
    """
    conn = None
    try:
        conn = psycopg2.connect(**db_params)
        cursor = conn.cursor()

        df = pd.read_csv(csv_file_path, sep=separator, dtype=str, encoding=encoding)

        for col in numeric_columns_to_clean:
            if col in df.columns:
                df[col] = df[col].str.replace(' ', '', regex=False)

        for col in date_columns:
            if col in df.columns:
                df[col] = pd.to_datetime(df[col], format='%d/%m/%y', errors='coerce').dt.strftime('%Y-%m-%d')

        for col in timestamp_columns:
            if col in df.columns:
                df[col] = pd.to_datetime(df[col], format='%d/%m/%y %H:%M:%S', errors='coerce').dt.strftime('%Y-%m-%d %H:%M:%S')
        
        df = df.replace({pd.NaT: None, np.nan: None, '': None})

        csv_buffer = StringIO()
        df.to_csv(csv_buffer, index=False, header=False, sep=separator)
        csv_buffer.seek(0)

        cursor.copy_from(csv_buffer, table_name, sep=separator, null='')

        conn.commit()
        print(f"Datos cargados exitosamente en la tabla '{table_name}' desde '{csv_file_path}'.")

    except Exception as e:
        print(f"Ocurrió un error: {e}")
        if conn:
            conn.rollback()
    finally:
        if conn:
            cursor.close()
            conn.close()
            print("Conexión a la base de datos cerrada.")

# --- Configuración ---
db_connection_params = {
    "dbname": "data4pyspark",
    "user": "mi19291",
    "password": "1ALEMAN9",
    "host": "localhost"
}

table_name = "TSCA010_SIPEMPLEADO"

file_path_kyc = f"/Users/mi19291/Downloads/Querys-Finales/CasosParaDataDevelopment/{table_name}.csv"
target_table_kyc = table_name.lower()
load_data_from_csv(
    file_path_kyc,
    target_table_kyc,
    db_connection_params,
    separator='|',
    date_columns= ['FH_ENVIO', 'FH_VENCIMIENTO', 'FH_ENVIO_SIA', 'FH_RESPUESTA_SIA', 'FH_ALERTA',\
                   'FH_REP_AUT', 'FH_ASIGNACION', 'FH_GEN', 'FH_PROCESO', 'FH_VEN_LIB_SIA', 'FH_VEN_REV',\
                    'FH_APERTURA', 'FH_DICTAMEN_FIN', 'FH_RECONSIDERA', 'FH_DICTAMEN_PRE', 'FH_ASIGNA',\
                    'FH_NACIMIENTO', 'FH_MODIFICA', 'FH_ALTA_CTE', 'FH_MOV', 'FH_CONTABLE', 'FH_OPERACION',\
                    'FH_VALOR', 'FH_CARGA', 'FH_CAMB_RIESGO', 'FH_ALTO_RIESGO', 'FH_REPORTE', 'FH_FOLIO',\
                    'FH_ASIGNA_SIA', 'FH_LIBERA_SIA', 'FH_PERIODO_INI', 'FH_PERIODO_FIN', 'FH_REPAUT'],
    timestamp_columns=['TM_VENCIMIENTO_SIA'],
    numeric_columns_to_clean=[] 
)
# Out:
# Datos cargados exitosamente en la tabla 'tsca010_sipempleado' desde '/Users/mi19291/Downloads/Querys-Finales/CasosParaDataDevelopment/TSCA010_SIPEMPLEADO.csv'.
# Conexión a la base de datos cerrada.

# %%
import pandas as pd

# 1. Definir la ruta del archivo y el nombre de la columna
# Reemplaza con tus propios valores.
ruta_archivo = 'CasosParaDataDevelopment/TSCA013_ALERTA.csv'
nombre_columna = 'CD_TIPOLOGIA'

try:
    # 2. Leer el archivo CSV con pandas
    # pandas asume por defecto que la primera fila es el encabezado.
    df = pd.read_csv(ruta_archivo, sep="|", encoding="latin1")
    
    # 3. Obtener los valores únicos de la columna especificada
    # Se selecciona la columna como una Serie y el método .unique() devuelve un array con los valores únicos.
    valores_unicos = df[nombre_columna].dropna().astype(str).unique()
    
    # 4. Imprimir los resultados
    print(f"Valores únicos encontrados en la columna '{nombre_columna}':")
    print(list(valores_unicos)) # Se convierte a lista para una mejor visualización
    print(f"\nTotal de valores únicos: {len(valores_unicos)}")

except FileNotFoundError:
    print(f"Error: No se encontró el archivo en la ruta especificada: '{ruta_archivo}'")
except KeyError:
    print(f"Error: La columna '{nombre_columna}' no existe en el archivo. Revisa el nombre.")
    print(f"Columnas disponibles: {list(df.columns)}")
except Exception as e:
    print(f"Ocurrió un error inesperado: {e}")
# Out:
# Valores únicos encontrados en la columna 'CD_TIPOLOGIA':
# ['SW', 'DC', 'E3', 'MD', 'MP', 'PS', 'R7', 'RD', 'RN', 'CQ', 'M2', 'RX']
#
# Total de valores únicos: 12

# %%
# --- CONFIGURACIÓN ---
import psycopg2
import pandas as pd

db_connection_params = {
    "dbname": "data4pyspark",
    "user": "mi19291",
    "password": "1ALEMAN9",
    "host": "localhost"
}

# %%
CD_SISTEMA = "'MDE', 'CCC', 'EFE', 'SPI', 'CBI', 'CHQ', 'AML', 'ATM'"
CD_ALERTA = "'202403013601', '202309015801', '202501008301', '1073130', '1122165', '9230800069501', '9230800069502', '2506271215', '2506301306', '2402295596601', '2307315770001', '1155423', '2501000828', '2503001736', '51472272', '9240200078701', '9240200078702', '2503315305201', '2025020758', '2501315997401', '2412316727501'"
CD_CASO = "1071288, 994651, 1185772, 1084150, 1061041, 968335, 1246109, 1176615, 1197600, 1198373, 1180636, 1168766"
NU_CLIENTE_LIST = "D1714830, 97690262, E1395002, E1447669, 75816071, A4782243, A2480820, D5631652, J2018888, E1332464, 98903126, 98903258, 98903277, 98903330, 98903339"
CD_TIPOLOGIA_LIST = "'SW', 'DC', 'E3', 'MD', 'MP', 'PS', 'R7', 'RD', 'RN', 'CQ', 'M2', 'RX'"

# %% [markdown]
# ## Consulta 0

# %%
miquery0 = """
    SELECT
        AL.CD_SISTEMA AS cdSistema,
        AL.CD_ALERTA AS cdAlerta,
        AL.FH_ALERTA AS fhAlerta,
        AL.FH_ENVIO AS fhEnvio,
        AL.CD_TIPOLOGIA AS cdTipologia,
        AL.CD_DIVISA AS cdDivisa,
        AL.ST_ALERTA AS cdStAlerta,
        AL.TX_MOTIVO_DESCARTE AS txMotivoDescarte,
        AL.ST_REP_AUT AS stRepAut,
        AL.NU_SCORE_MC AS scoreMc,
        AL.NU_SCORE_MD AS scoreMdl,
        AL.FH_VEN_LIB_SIA AS fhVenLibSia,
        AL.FH_REP_AUT AS fhRepAut,
        AL.FH_ASIGNACION AS fhAsignacion,
        AL.FH_VEN_REV AS fhVenRev,
        AL.CD_SEG AS cdSeg,
        AL.NU_SESION_ORIGEN AS cdSesion,
        AL.IM_MONTO_ALERTA AS imMontoAlerta,
        AL.CD_CLIENTE AS cdCliente,
        AL.NU_CUENTA AS nuCuenta,
        AL.CD_CASO AS cdCaso,
        AL.CD_PERIODO AS cdPeriodo,
        AL.CD_CTE AS cdCte,
        CASE WHEN AL.CD_ACCION = 'D' THEN 'ALERTA' WHEN AL.CD_ACCION = 'N' THEN 'NOTIFICACION' WHEN AL.CD_ACCION = 'I' THEN 'INEPA' END AS cdAccion,
        -- CAMBIO: NVL anidado reemplazado por un solo COALESCE
        COALESCE(AL.NB_NOMBRE, AL.NB_CTE, AL.NB_NOMBRE_CTE) AS nbCte,
        (SELECT CD_OFICINA || ' - ' ||NB_OFICINA FROM TSCA003_OFICINA WHERE CD_OFICINA = AL.CD_OFICINA_GEST) AS cdOficinaGest,
        AL.NB_BANCA AS nbBanca,
        AL.CD_MATCH AS cdMatch,
        AL.IM_SCORE AS imScore,
        AL.CT_MOVIMIENTO AS ctMovimiento,
        AL.CD_DIRECTA AS cdDirecta,
        AL.NU_SCORE_CORTE AS nuScoreCorte,
        COALESCE(AL.NB_NOMBRE, AL.NB_CTE, AL.NB_NOMBRE_CTE) AS nbNombreCte,
        AL.NB_APPATERNO_CTE AS nbAppaternoCte,
        AL.NB_APMATERNO_CTE AS nbApmaternoCte,
        AL.NU_OPER AS nuOper,
        AL.FH_NAC AS fhNac,
        AL.NU_EDAD AS nuEdad,
        AL.CD_SECTOR AS cdSector,
        AL.FH_APERTURA AS fhApertura,
        AL.NB_SUC_APERTURA AS nbSucApertura,
        AL.CD_CENTRO_SUP AS cdCentroSup,
        AL.NB_DIVISION AS nbDivision,
        AL.NB_ESTADO AS nbEstado,
        AL.NB_ACT_ECO_BXICO AS nbActividad,
        AL.TP_SECTOR AS tpSector,
        -- CAMBIO: Formato de fecha RRRR corregido a YYYY
        to_char((to_date('01-01-1900','DD-MM-YYYY')+ AL.NU_ANTIGUEDAD )-2,'DD/MM/YYYY') AS nuAntiguedad,
        AL.CD_SUCURSAL AS cdSucursal,
        AL.CD_DIR_ZONA AS cdDirZona,
        AL.FH_GEN AS fhGen,
        AL.CD_ACT_ECO_BXICO AS cdActividad,
        -- CAMBIO: Todos los NVL se reemplazan por COALESCE
        COALESCE(AL.NU_DEP,0) AS nuDep,
        COALESCE(AL.IM_IMPORTE_DEP,0) AS imImporteDep,
        COALESCE(AL.IM_IMPORTE_RET,0) AS imImporteRet,
        COALESCE(AL.NU_RET,0) AS nuRet,
        COALESCE(AL.NU_CV,0) AS nuCv,
        COALESCE(AL.IM_IMPORTE_CV,0) AS imImporteCv,
        COALESCE(AL.CD_MOV_OTRO,0) AS cdMovOtro,
        COALESCE(AL.IM_IMP_OTRO,0) AS imImpOtro,
        AL.NU_FOLIO_IFI AS nuFolioIfi,
        COALESCE(AL.NB_NOMBRE, AL.NB_CTE, AL.NB_NOMBRE_CTE) AS nbNombre
FROM
        TSCA013_ALERTA AL
WHERE 
        -- CAMBIO: Se usan operadores IN para aceptar listas de valores
        AL.CD_ALERTA IN (&CD_ALERTA_LIST) AND
        AL.CD_SISTEMA IN (&CD_SISTEMA_LIST) AND
        AL.CD_TIPOLOGIA IN (&CD_TIPOLOGIA_LIST);
"""

# %%
import re

query_in = miquery0.replace("&CD_SISTEMA_LIST", CD_SISTEMA)\
    .replace("&CD_ALERTA_LIST", CD_ALERTA)\
    .replace("&CD_CASO_LIST", CD_CASO)\
    .replace("&CD_TIPOLOGIA_LIST", CD_TIPOLOGIA_LIST)

query_segura = re.sub(r'&\w+', '%s', query_in)

print("\nConectando a la base de datos y ejecutando la consulta...")
conn = psycopg2.connect(**db_connection_params)
cursor = conn.cursor()

cursor.execute(query_segura)

if cursor.rowcount == 0:
    print("\nLa consulta se ejecutó correctamente, pero no arrojó resultados.")

columnas = [desc[0] for desc in cursor.description]

registros = cursor.fetchall()

df = pd.DataFrame(registros, columns=columnas)

print("\n--- Resultados de la Consulta ---")
print(df.to_string())

print("\nGuardando los resultados en un archivo Parquet...")
df.to_csv('parquet/salidas/query_zero', index=False)
print("¡Archivo 'resultados_consulta.parquet' guardado con éxito!")
# Out:
# Conectando a la base de datos y ejecutando la consulta...
#
# --- Resultados de la Consulta ---
#    cdsistema       cdalerta    fhalerta     fhenvio cdtipologia cddivisa  cdstalerta                                                                                       txmotivodescarte strepaut     scoremc     scoremdl fhvenlibsia    fhrepaut fhasignacion    fhvenrev cdseg cdsesion immontoalerta cdcliente              nucuenta     cdcaso cdperiodo     cdcte      cdaccion                                                          nbcte                                cdoficinagest          nbbanca       cdmatch  imscore  ctmovimiento  cddirecta nuscorecorte                                                    nbnombrecte nbappaternocte nbapmaternocte nuoper fhnac nuedad cdsector  fhapertura nbsucapertura cdcentrosup nbdivision nbestado                    nbactividad tpsector nuantiguedad cdsucursal cddirzona       fhgen cdactividad  nudep imimportedep imimporteret  nuret  nucv imimportecv  cdmovotro imimpotro  nufolioifi                                                       nbnombre
# 0        MDE   202403013601  2024-03-31  2024-04-18          SW      MXP           3                                                                                                   None     None        0E-8   7.27975951  2024-05-08  2024-06-16   2024-04-20  2024-05-03   PRI     None     158634.14  A4782243  00744485002914964810  1071288.0    202404      None        ALERTA                                           ARIADNE GARZA HUGHES            4485 - MONTERREY CENTRO PRINCIPAL  BANCA COMERCIAL          None     77.0           3.0        0.0         6.90                                           ARIADNE GARZA HUGHES           None           None   None  None   None     None        None          None        None       None     None                      EDUCACION     None         None       None      None  2024-04-20        None      0            0            0      0     0           0          0         0  2024030136                                           ARIADNE GARZA HUGHES
# 1        MDE   202309015801  2023-09-30  2023-10-27          SW      MXP           3                                                                                                   None     None        0E-8   7.45739608  2023-11-16  2023-12-25   2023-10-31  2023-11-11   PRI     None     111390.00  A4782243  00744485002914964810   994651.0    202310      None        ALERTA                                           ARIADNE GARZA HUGHES            4485 - MONTERREY CENTRO PRINCIPAL  BANCA COMERCIAL          None     59.0           2.0        0.0         7.00                                           ARIADNE GARZA HUGHES           None           None   None  None   None     None        None          None        None       None     None                      EDUCACION     None         None       None      None  2023-10-31        None      0            0            0      0     0           0          0         0  2023090158                                           ARIADNE GARZA HUGHES
# 2        MDE   202501008301  2025-01-31  2025-02-14          SW      MXP           4                                                                                                   None     None        0E-8   7.27724546  2025-03-06  2025-04-14   2025-02-20  2025-03-01   PRI     None     115150.00  A4782243  00744485002914964810  1185772.0    202502      None        ALERTA                                           ARIADNE GARZA HUGHES            4485 - MONTERREY CENTRO PRINCIPAL  BANCA COMERCIAL          None     64.0           1.0        0.0         6.90                                           ARIADNE GARZA HUGHES           None           None   None  None   None     None        None          None        None       None     None                      EDUCACION     None         None       None      None  2025-02-20        None      0            0            0      0     0           0          0         0  2025010083                                           ARIADNE GARZA HUGHES
# 3        CCC        1073130  2024-05-18  2024-05-18          DC      MXP           4                                                                                                   None     None        None  10.00000000  2024-06-07  2024-07-16   2024-05-18  2024-06-02   000     None          0.00  D1714830            0118876274  1084150.0      None  D1714830        ALERTA  SERVICIOS INDUSTRIAL ES E INGENIERIA CIVI L CMJ S DE RL DE CV                         1513 - PLAZA PLATI2M  BANCA COMERCIAL          None      NaN           NaN        NaN         None  SERVICIOS INDUSTRIAL ES E INGENIERIA CIVI L CMJ S DE RL DE CV           None           None   None  None   None     None        None          None        None       None     None                           None     None         None       None      None  2024-05-18        None      0            0            0      0     0           0          0         0        None  SERVICIOS INDUSTRIAL ES E INGENIERIA CIVI L CMJ S DE RL DE CV
# 4        CCC        1122165  2025-02-27  2025-02-27          E3      MXP           3       DESCARTE POR TENER UN CASO PREVIO DE INVESTIGACION NO MAYOR A 6 MESES:404872:SIN DECISION EN SIA     None        0E-8   8.45462518  2025-03-19  2025-04-27         None  2025-03-14   000     None          0.00  D1714830            0118876274        NaN      None  D1714830        ALERTA    SERVICIOS INDUSTRIALES E INGENIERIA CIVIL CMJ S DE RL DE CV                                         None             None          None      NaN           NaN        NaN         None    SERVICIOS INDUSTRIALES E INGENIERIA CIVIL CMJ S DE RL DE CV           None           None   None  None   None     None        None          None        None       None     None                           None     None         None       None      None        None        None      0            0            0      0     0           0          0         0        None    SERVICIOS INDUSTRIALES E INGENIERIA CIVIL CMJ S DE RL DE CV
# 5        EFE  9230800069501  2023-06-30  2023-08-07          MD      MXP           3                                                                   DESCARTE POR NOTIFICACION NO INUSUAL     None        None         None  2023-08-27  2023-10-05         None  2023-08-22   MCO     None     550000.00  D1714830  00741513000118876274        NaN    202307      None  NOTIFICACION    SERVICIOS INDUSTRIALES E INGENIERIA CIVIL CMJ S DE RL DE CV                         1513 - PLAZA PLATI2M  BANCA COMERCIAL   23070810805     87.0           1.0        0.0         3.67    SERVICIOS INDUSTRIALES E INGENIERIA CIVIL CMJ S DE RL DE CV           None           None   None  None   None     None        None          None        None       None     None                           None     None         None       None      None        None        None      0            0            0      0     0           0          0         0        None    SERVICIOS INDUSTRIALES E INGENIERIA CIVIL CMJ S DE RL DE CV
# 6        EFE  9230800069502  2023-06-30  2023-08-07          MP      MXP           3                                                                   DESCARTE POR NOTIFICACION NO INUSUAL     None        None         None  2023-08-27  2023-10-05         None  2023-08-22   MCO     None    1313111.00  D1714830  00741513000118876274        NaN    202307      None  NOTIFICACION    SERVICIOS INDUSTRIALES E INGENIERIA CIVIL CMJ S DE RL DE CV                         1513 - PLAZA PLATI2M  BANCA COMERCIAL   23070726044     84.0           7.0        0.0         3.67    SERVICIOS INDUSTRIALES E INGENIERIA CIVIL CMJ S DE RL DE CV           None           None   None  None   None     None        None          None        None       None     None                           None     None         None       None      None        None        None      0            0            0      0     0           0          0         0        None    SERVICIOS INDUSTRIALES E INGENIERIA CIVIL CMJ S DE RL DE CV
# 7        SPI     2506271215  2025-06-27  2025-07-01          PS      USD           3   DESCARTE POR TENER UN CASO PREVIO DE INVESTIGACION NO MAYOR A 6 MESES:404872:INUSUAL CONDICIONADA 00     None  8.00000000   7.18084833  2025-07-26  2025-08-29         None  2025-07-21   MCO     None     206135.63  D1714830  00741513000119752161        NaN    202507         0        ALERTA    SERVICIOS INDUSTRIALES E INGENIERIA CIVIL CMJ S DE RL DE CV           1735 - CENTRO PYME CHIHUAHUA PLAZA  BANCA COMERCIAL  2.0250627E12     61.0           4.0        0.0         6.90    SERVICIOS INDUSTRIALES E INGENIERIA CIVIL CMJ S DE RL DE CV           None           None   None  None   None      M31        None          None        None       None     None                       UB;BACOM     None         None       None      None        None        None      0            0            0      0     0           0          0         0        None    SERVICIOS INDUSTRIALES E INGENIERIA CIVIL CMJ S DE RL DE CV
# 8        SPI     2506301306  2025-06-30  2025-07-02          PS      USD           3   DESCARTE POR TENER UN CASO PREVIO DE INVESTIGACION NO MAYOR A 6 MESES:404872:INUSUAL CONDICIONADA 00     None  8.00000000   7.19047340  2025-07-27  2025-08-30         None  2025-07-22   MCO     None     203343.63  D1714830  00741513000119752161        NaN    202507         0        ALERTA    SERVICIOS INDUSTRIALES E INGENIERIA CIVIL CMJ S DE RL DE CV           1735 - CENTRO PYME CHIHUAHUA PLAZA  BANCA COMERCIAL   2.025063E12     51.0           3.0        0.0         6.90    SERVICIOS INDUSTRIALES E INGENIERIA CIVIL CMJ S DE RL DE CV           None           None   None  None   None      M31        None          None        None       None     None                       UB;BACOM     None         None       None      None        None        None      0            0            0      0     0           0          0         0        None    SERVICIOS INDUSTRIALES E INGENIERIA CIVIL CMJ S DE RL DE CV
# 9        EFE  2402295596601  2024-02-29  2024-03-25          R7      MXP           3                                                                                                   None     None        None   7.89092913  2024-04-14  2024-05-23   2024-03-27  2024-04-09   MCO     None    4875100.00  D1714830  00741513000118876274  1061041.0    202403         0        ALERTA    SERVICIOS INDUSTRIALES E INGENIERIA CIVIL CMJ S DE RL DE CV                         1513 - PLAZA PLATI2M  BANCA COMERCIAL   24030724273     96.0           1.0        0.0         7.74    SERVICIOS INDUSTRIALES E INGENIERIA CIVIL CMJ S DE RL DE CV           None           None   None  None   None     None        None          None        None       None     None                       UB;BACOM     None         None       None      None  2024-03-27        None      0            0            0      0     0           0          0         0        None    SERVICIOS INDUSTRIALES E INGENIERIA CIVIL CMJ S DE RL DE CV
# 10       EFE  2307315770001  2023-07-31  2023-08-28          R7      MXP           3                                                                                                   None     None        None   7.35880456  2023-09-17  2023-10-26   2023-08-31  2023-09-12   MCO     None    2829600.00  D1714830  00741513000118876274   968335.0    202308         0        ALERTA    SERVICIOS INDUSTRIALES E INGENIERIA CIVIL CMJ S DE RL DE CV                         1513 - PLAZA PLATI2M  BANCA COMERCIAL   23080725229     91.0           9.0        0.0         4.50    SERVICIOS INDUSTRIALES E INGENIERIA CIVIL CMJ S DE RL DE CV           None           None   None  None   None     None        None          None        None       None     None                       UB;BACOM     None         None       None      None  2023-08-31        None      0            0            0      0     0           0          0         0        None    SERVICIOS INDUSTRIALES E INGENIERIA CIVIL CMJ S DE RL DE CV
# 11       CCC        1155423  2025-07-26  2025-07-26          RD      MXP           3  :DESCARTE POR TENER UN CASO PREVIO DE INVESTIGACION NO MAYOR A 6 MESES:404872:INUSUAL CONDICIONADA 00     None        None  10.00000000  2025-08-15  2025-09-23   2025-07-26  2025-08-10   000     None          0.00  D1714830            0119752161  1246109.0      None  D1714830        ALERTA                                                           None                         1513 - PLAZA PLATI2M  BANCA COMERCIAL          None      NaN           NaN        NaN         None                                                           None           None           None   None  None   None     None        None          None        None       None     None                           None     None         None       None      None  2025-07-26        None      0            0            0      0     0           0          0         0        None                                                           None
# 12       CBI     2501000828  2024-12-31  2025-01-28          RN      MXP           4                                                                                                   None     None        None   7.53742996  2025-02-17  2025-03-28   2025-01-30  2025-02-12   MCO     None     700600.00  D1714830  00741513000118876274  1176615.0    202501      None        ALERTA  SERVICIOS INDUSTRIAL ES E INGENIERIA CIVI L CMJ S DE RL DE CV                         1513 - PLAZA PLATI2M  BANCA COMERCIAL          None     55.0           3.0        0.0         7.00  SERVICIOS INDUSTRIAL ES E INGENIERIA CIVI L CMJ S DE RL DE CV           None           None   None  None   None     None  2022-06-08          None        None       None     None                          OTROS     None         None       None      None  2025-01-30        None      0            0            0      0     0           0          0         0        None  SERVICIOS INDUSTRIAL ES E INGENIERIA CIVI L CMJ S DE RL DE CV
# 13       CHQ     2503001736  2025-02-28  2025-03-24          CQ      MXP           4                                                                                                   None     None        None   7.32766798  2025-04-13  2025-05-22   2025-03-26  2025-04-08   MCO     None     300000.00  D5631652  00745765000120584754  1197600.0    202503      None        ALERTA   SUMINISTROS, MATERIA LES,RENTA Y FLETES P ARA OBRAS SA DE CV       5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  BANCA COMERCIAL          None     55.0           1.0        0.0         7.20   SUMINISTROS, MATERIA LES,RENTA Y FLETES P ARA OBRAS SA DE CV           None           None   None  None   None     None  2023-06-17          None        None       None     None  TRANSP.MATERIALES DE CONSTRUC     None         None       None      None  2025-03-26        None      0            0            0      0     0           0          0         0        None   SUMINISTROS, MATERIA LES,RENTA Y FLETES P ARA OBRAS SA DE CV
# 14       AML       51472272  2025-05-07  2025-05-14          M2      MXP           3       DESCARTE POR TENER UN CASO PREVIO DE INVESTIGACION NO MAYOR A 6 MESES:411415:INUSUAL CANCELAR 01     None  5.00000000   7.81607452  2025-06-03  2025-07-12         None  2025-05-29   MCO     None    6575000.00  D5631652  00745765000120584754        NaN    202505      None        ALERTA      SUMINISTROS MATERIALES RENTA Y FLETES PARA OBRAS SA DE CV       5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  BANCA COMERCIAL          None    483.0           9.0        0.0         7.80      SUMINISTROS MATERIALES RENTA Y FLETES PARA OBRAS SA DE CV           None           None   None  None   None     None  2023-06-17          None        None       None     None  TRANSP.MATERIALES DE CONSTRUC     None         None       None      None        None        None      0            0            0      0     0           0          0         0        None      SUMINISTROS MATERIALES RENTA Y FLETES PARA OBRAS SA DE CV
# 15       EFE  9240200078701  2023-12-29  2024-02-08          MD      MXP           3                                                                   DESCARTE POR NOTIFICACION NO INUSUAL     None        None         None  2024-02-28  2024-04-07         None  2024-02-23   MCO     None     800000.00  D5631652  00745765000120584754        NaN    202401      None  NOTIFICACION     SUMINISTROS, MATERIALES,RENTA Y FLETES PARA OBRAS SA DE CV       5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  BANCA COMERCIAL   24010812973     97.0           1.0        0.0         7.71     SUMINISTROS, MATERIALES,RENTA Y FLETES PARA OBRAS SA DE CV           None           None   None  None   None     None        None          None        None       None     None                           None     None         None       None      None        None        None      0            0            0      0     0           0          0         0        None     SUMINISTROS, MATERIALES,RENTA Y FLETES PARA OBRAS SA DE CV
# 16       EFE  9240200078702  2023-12-29  2024-02-08          MP      MXP           3                                                                   DESCARTE POR NOTIFICACION NO INUSUAL     None        None         None  2024-02-28  2024-04-07         None  2024-02-23   MCO     None    1560000.00  D5631652  00745765000120584754        NaN    202401      None  NOTIFICACION     SUMINISTROS, MATERIALES,RENTA Y FLETES PARA OBRAS SA DE CV       5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  BANCA COMERCIAL   24010728881     86.0           6.0        0.0         7.71     SUMINISTROS, MATERIALES,RENTA Y FLETES PARA OBRAS SA DE CV           None           None   None  None   None     None        None          None        None       None     None                           None     None         None       None      None        None        None      0            0            0      0     0           0          0         0        None     SUMINISTROS, MATERIALES,RENTA Y FLETES PARA OBRAS SA DE CV
# 17       EFE  2503315305201  2025-03-31  2025-04-22          R7      MXP           3       DESCARTE POR TENER UN CASO PREVIO DE INVESTIGACION NO MAYOR A 6 MESES:411415:SIN DECISION EN SIA     None        None   7.87676530  2025-05-12  2025-06-20         None  2025-05-07   MCO     None    5600000.00  D5631652  00745765000120584754        NaN    202504         0        ALERTA     SUMINISTROS, MATERIALES,RENTA Y FLETES PARA OBRAS SA DE CV       5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  BANCA COMERCIAL   25040724533     96.0          11.0        0.0         7.75     SUMINISTROS, MATERIALES,RENTA Y FLETES PARA OBRAS SA DE CV           None           None   None  None   None     None        None          None        None       None     None                       UB;BACOM     None         None       None      None        None        None      0            0            0      0     0           0          0         0        None     SUMINISTROS, MATERIALES,RENTA Y FLETES PARA OBRAS SA DE CV
# 18       ATM     2025020758  2025-02-28  2025-03-25          RX      MXP           4                                                                                                   None     None        None   7.31668245  2025-04-14  2025-05-23   2025-03-28  2025-04-09   PRI     None      24237.26  E1332464  00743607001529864740  1198373.0    202503      None        ALERTA                                      JOVIBIANO SANTIAGO CARMEN  3607 - D.F. SERVICIOS BANCARIOS AL PERSONAL  BANCA COMERCIAL          None     55.0           7.0        0.0         7.20                                      JOVIBIANO SANTIAGO CARMEN           None           None   None  None   None     None  2024-10-29          None        None       None     None                           None     None         None       None      None  2025-03-28        None      0            0            0      0     0           0          0         0        None                                      JOVIBIANO SANTIAGO CARMEN
# 19       EFE  2501315997401  2025-01-31  2025-02-07          R7      MXP           4                                                                                                   None     None        None   9.68108075  2025-02-27  2025-04-07   2025-02-13  2025-02-22   RES     None    1181647.00  E1395002  00747696000124019989  1180636.0    202502         0        ALERTA                                        MUNICIPIO DE ELDORAD O                       7696 - GOBIERNO SINALOA             BEYG   25020727618     83.0           5.0        0.0         7.79                                        MUNICIPIO DE ELDORAD O            None           None   None  None   None     None        None          None        None       None     None                  MB;BACOM;BEYG     None         None       None      None  2025-02-13        None      0            0            0      0     0           0          0         0        None                                        MUNICIPIO DE ELDORAD O
# 20       EFE  2412316727501  2024-12-31  2025-01-10          R7      MXP           3                                                                                                   None     None        None   9.29643009  2025-01-30  2025-03-10   2025-01-14  2025-01-25   RES     None     726672.00  E1395002  00747696000124019989  1168766.0    202501         0        ALERTA                                          MUNICIPIO DE ELDORADO                      7696 - GOBIERNO SINALOA             BEYG   25010308888     76.0           4.0        0.0         7.79                                          MUNICIPIO DE ELDORADO           None           None   None  None   None     None        None          None        None       None     None                  MB;BACOM;BEYG     None         None       None      None  2025-01-14        None      0            0            0      0     0           0          0         0        None                                          MUNICIPIO DE ELDORADO
#
# Guardando los resultados en un archivo Parquet...
# ¡Archivo 'resultados_consulta.parquet' guardado con éxito!

# %% [markdown]
# ## Consulta 2
#
# - **TSCA010_SIPEMPLEADO:**
#
# Si no se encuentra un empleado que cumpla las condiciones, la columna nbFuncionarioIR quedará nula.
# - **TSCA065_CENTRO_RESP:**
#
# Si una oficina no tiene un registro correspondiente aquí, las columnas nbOficinaGestoraIR, nbMercadoIR, nbDivisionIR y nbFuncionarioIR probablemente quedarán nulas para ese registro
# - **TSCA073_FUNCIONARIO:**
#
# La tabla podría ser eliminada de la consulta sin afectar el resultado y, de hecho, la haría ligeramente más rápida.
# - **TSCA100_SIPPUESTO:**
#
# Si la tabla está vacía o no existen los perfiles buscados, la subconsulta no encontrará a ningún funcionario que cumpla la condición, y la columna nbFuncionarioIR quedará nula.

# %%
mi_query2 = """
SELECT
    nuFolioAlertaIR,
    cdCaso,
    nbSistemaIR,
    nuCuentaIR,
    montoIR,
    divisaIR,
    fhAlertaIR,
    fhEnvioIR,
    cdSesionIR,
    nbOficinaGestoraIR,
    nbRiesgoIR,
    nbMercadoIR,
    nbDivisionIR,
    nbFuncionarioIR
FROM
(SELECT
        T13.CD_ALERTA nuFolioAlertaIR,
        T13.CD_CASO cdCaso,
        T06.CD_SISTEMA nbSistemaIR,
        T13.NU_CUENTA nuCuentaIR,
        T13.IM_MONTO_ALERTA montoIR,
        T13.CD_DIVISA divisaIR,
        T13.FH_ALERTA fhAlertaIR,
        T13.FH_ENVIO fhEnvioIR,
        T13.CD_SESION cdSesionIR,
        (SELECT CD_OFICINA ||' '|| NB_CENTRO_RESP FROM TSCA065_CENTRO_RESP WHERE CD_OFICINA = T65.CD_CENTRO_RESP7) nbOficinaGestoraIR,
        (SELECT NB_RIESGO FROM TSCA003_OFICINA WHERE CD_OFICINA = CAST(T65.CD_CENTRO_RESP7 AS INTEGER)) nbRiesgoIR,
        (SELECT NB_CENTRO_RESP FROM TSCA065_CENTRO_RESP WHERE CD_OFICINA = T65.CD_CENTRO_RESP6) nbMercadoIR,
        (SELECT CD_OFICINA ||' '|| NB_CENTRO_RESP FROM TSCA065_CENTRO_RESP WHERE CD_OFICINA = T65.CD_CENTRO_RESP5) nbDivisionIR,
        (
                SELECT
                        DISTINCT (T10.NB_EMPLEADO ||' ' || T10.NB_APPATERNO ||' ' || T10.NB_APMATERNO)
                FROM
                        TSCA010_SIPEMPLEADO T10,
                        TSCA100_SIPPUESTO T100
                WHERE
                        TRIM(T100.CD_PUESTO) = TRIM(T10.CD_PUESTO)
                        AND CD_USUARIO IS NOT NULL
                        AND TRIM(T100.CD_PERFIL) IN ('0001', '0022', '0041')
                        AND CAST(T10.CD_CENT_COSTO AS INTEGER) = CAST(T65.CD_CENTRO_RESP7 AS INTEGER)
                        LIMIT 1
    ) nbFuncionarioIR
FROM
        TSCA014_CASO T14
        LEFT JOIN TSCA016_CLIENTE T16 ON (T14.CD_CASO = T16.CD_CASO AND T14.CD_CLIENTE = T16.CD_CLIENTE)
        LEFT JOIN TSCA013_ALERTA T13 ON T14.CD_CASO = T13.CD_CASO
        LEFT JOIN TSCA006_SISTEMA T06 ON T13.CD_SISTEMA = T06.CD_SISTEMA
        LEFT JOIN TSCA003_OFICINA T03 ON T13.CD_OFICINA_GEST = T03.CD_OFICINA
        LEFT JOIN TSCA010_SIPEMPLEADO T10 ON T03.CD_OFICINA = CAST(T10.CD_CENT_COSTO AS INTEGER)
        LEFT JOIN TSCA065_CENTRO_RESP T65 ON T16.CD_OFICINA = CAST(T65.CD_OFICINA AS INTEGER)
WHERE
        T13.CD_ALERTA IN (&CD_ALERTA_LIST)
        AND T13.CD_SISTEMA IN (&CD_SISTEMA_LIST)
) AS SubconsultaPrincipal
GROUP BY nuFolioAlertaIR,cdCaso,nbSistemaIR,nuCuentaIR,montoIR,divisaIR,fhAlertaIR,fhEnvioIR,cdSesionIR,nbOficinaGestoraIR,nbRiesgoIR,nbMercadoIR,nbDivisionIR,nbFuncionarioIR;
"""

# %%
import re

query_in = mi_query2.replace("&CD_SISTEMA_LIST", CD_SISTEMA)\
    .replace("&CD_ALERTA_LIST", CD_ALERTA)\
    .replace("&CD_CASO_LIST", CD_CASO)

query_segura = re.sub(r'&\w+', '%s', query_in)

print("\nConectando a la base de datos y ejecutando la consulta...")
conn = psycopg2.connect(**db_connection_params)
cursor = conn.cursor()

cursor.execute(query_segura)

if cursor.rowcount == 0:
    print("\nLa consulta se ejecutó correctamente, pero no arrojó resultados.")

columnas = [desc[0] for desc in cursor.description]

registros = cursor.fetchall()

df = pd.DataFrame(registros, columns=columnas)

print("\n--- Resultados de la Consulta ---")
print(df.to_string())

print("\nGuardando los resultados en un archivo Parquet...")
df.to_csv('parquet/salidas/query_dos.csv', index=False)
print("¡Archivo 'resultados_consulta.parquet' guardado con éxito!")
# Out:
# Conectando a la base de datos y ejecutando la consulta...
#
# --- Resultados de la Consulta ---
#   nufolioalertair   cdcaso nbsistemair            nucuentair     montoir divisair  fhalertair   fhenvioir cdsesionir                         nboficinagestorair  nbriesgoir       nbmercadoir                        nbdivisionir                        nbfuncionarioir
# 0    202501008301  1185772         MDE  00744485002914964810   115150.00      MXP  2025-01-31  2025-02-14    14-2025                               5258 CERCADO  MEDIO ALTO  DZ MONTERREY SUR                  3390 DIV. NOROESTE          CLAUDIA ESTHELA CABELLO LOPEZ
# 1      2025020758  1198373         ATM  00743607001529864740    24237.26      MXP  2025-02-28  2025-03-25    14-2025  3607 D.F. SERVICIOS BANCARIOS AL PERSONAL  MEDIO BAJO       DZ COYOACAN  3170 DIV. METROPOLITANA ADJUNTA II                                   None
# 2      2501000828  1176615         CBI  00741513000118876274   700600.00      MXP  2024-12-31  2025-01-28    06-2025                                       None        None              None                                None                                   None
# 3   2501315997401  1180636         EFE  00747696000124019989  1181647.00      MXP  2025-01-31  2025-02-07    13-2025                      7696 GOBIERNO SINALOA        BAJO              None              2134 DIVISION NOROESTE                                   None
# 4      2503001736  1197600         CHQ  00745765000120584754   300000.00      MXP  2025-02-28  2025-03-24    14-2025       5765 PLAYA DEL CARMEN OFNA PRINCIPAL     EXTREMO         DZ CANCUN                   2660 DIV. SURESTE  GUADALUPE DEL ROSARIO ENRIQUEZ GARCIA
#
# Guardando los resultados en un archivo Parquet...
# ¡Archivo 'resultados_consulta.parquet' guardado con éxito!

# %% [markdown]
# ## Consulta 7

# %%
mi_query = """
SELECT
    T27.CD_CASO AS cdCaso,
    T27.FH_OPERACION AS fhOperacion,
    T27.CD_DIVISA AS nbMoneda,
    (SELECT NB_INS_MON FROM TSCA040_INST_MON WHERE CD_INS_MON = T27.CD_INST_MON::integer) AS nbInstrumento,
    (SELECT NB_OPERAC FROM TSCA029_TP_OPERAC WHERE TP_OPERAC = T27.TP_OPERACION) AS nbTipoTransaccion,
    T27.NU_CUENTA AS nuCuentas,
    T27.CD_FOLIO AS nbReferencia,
    T27.IM_MONTO AS imOperacion,
    T27.CD_OFICINA ||' - '||(SELECT NB_OFICINA FROM TSCA003_OFICINA WHERE CD_OFICINA = T27.CD_OFICINA) AS nbOficina,
    'RELEVANTES' AS tpOperacion
FROM
    TSCA027_OP_RELEV T27
JOIN TSCA016_CLIENTE T16
    ON (T16.CD_CLIENTE = T27.CD_CLIENTE AND T16.CD_CASO = T27.CD_CASO)
WHERE
    -- CAMBIO: AHORA ACEPTA UNA LISTA DE CASOS
    T27.CD_CASO IN (&CD_CASO_LIST)
    AND T27.CD_CLIENTE IN (
        SELECT CD_CLIENTE FROM TSCA013_ALERTA
        WHERE
            -- CAMBIO: SE AÑADE EL FILTRO DEL CASO AQUÍ PARA MAYOR EFICIENCIA
            CD_CASO IN (&CD_CASO_LIST)
            AND CD_ALERTA IN (&CD_ALERTA_LIST)
            AND CD_SISTEMA IN (&CD_SISTEMA_LIST)
    )
UNION ALL
SELECT
    T57.CD_CASO AS cdCaso,
    T57.FH_OPERACION AS fhOperacion,
    T57.CD_DIVISA AS nbMoneda,
    (SELECT NB_INS_MON FROM TSCA040_INST_MON WHERE CD_INS_MON = T57.CD_INST_MONE::integer) AS nbInstrumento,
    (SELECT NB_OPERAC FROM TSCA029_TP_OPERAC WHERE TP_OPERAC = T57.TP_OPERACION) AS nbTipoTransaccion,
    T57.NU_CUENTA AS nuCuentas,
    T57.CD_FOLIO AS nbReferencia,
    T57.IM_IMPORTE AS imOperacion,
    T57.CD_OFICINA ||' - '||(SELECT NB_OFICINA FROM TSCA003_OFICINA WHERE CD_OFICINA = T57.CD_OFICINA) AS nbOficina,
    'MEDIANAS' AS tpOperacion
FROM
    TSCA057_OP_MED T57
JOIN TSCA016_CLIENTE T16
    ON (T16.CD_CLIENTE = T57.CD_CLIENTE AND T16.CD_CASO = T57.CD_CASO)
WHERE
    -- CAMBIO: AHORA ACEPTA UNA LISTA DE CASOS
    T57.CD_CASO IN (&CD_CASO_LIST)
    AND T57.CD_CLIENTE IN (
        SELECT CD_CLIENTE FROM TSCA013_ALERTA
        WHERE
            -- CAMBIO: SE AÑADE EL FILTRO DEL CASO AQUÍ PARA MAYOR EFICIENCIA
            CD_CASO IN (&CD_CASO_LIST)
            AND CD_ALERTA IN (&CD_ALERTA_LIST)
            AND CD_SISTEMA IN (&CD_SISTEMA_LIST)
    );
"""

# %%
import re

query_in = mi_query.replace("&CD_SISTEMA_LIST", CD_SISTEMA)\
    .replace("&CD_ALERTA_LIST", CD_ALERTA)\
    .replace("&CD_CASO_LIST", CD_CASO)

query_segura = re.sub(r'&\w+', '%s', query_in)

print("\nConectando a la base de datos y ejecutando la consulta...")
conn = psycopg2.connect(**db_connection_params)
cursor = conn.cursor()

cursor.execute(query_segura)

if cursor.rowcount == 0:
    print("\nLa consulta se ejecutó correctamente, pero no arrojó resultados.")

columnas = [desc[0] for desc in cursor.description]

registros = cursor.fetchall()

df = pd.DataFrame(registros, columns=columnas)

print("\n--- Resultados de la Consulta ---")
print(df.to_string())

print("\nGuardando los resultados en un archivo Parquet...")
df.to_csv('parquet/salidas/query_siete.csv', index=False)
print("¡Archivo 'resultados_consulta.parquet' guardado con éxito!")
# Out:
# Conectando a la base de datos y ejecutando la consulta...
#
# --- Resultados de la Consulta ---
#       cdcaso fhoperacion nbmoneda nbinstrumento nbtipotransaccion             nucuentas nbreferencia imoperacion                               nboficina tpoperacion
# 0    1176615  2023-05-31      MXP      EFECTIVO            RETIRO  00741513000118876274       382860   379500.00                      887 - CAMPUS NORTE  RELEVANTES
# 1    1176615  2023-06-13      MXP      EFECTIVO            RETIRO  00741513000118876274       149453   406975.00                      887 - CAMPUS NORTE  RELEVANTES
# 2    1176615  2023-07-03      MXP      EFECTIVO            RETIRO  00741513000118876274       011328   150000.00                      887 - CAMPUS NORTE  RELEVANTES
# 3    1176615  2023-06-23      MXP      EFECTIVO            RETIRO  00741513000118876274       284455   550000.00                      887 - CAMPUS NORTE  RELEVANTES
# 4    1176615  2023-07-06      MXP      EFECTIVO            RETIRO  00741513000118876274       066226   292000.00                      887 - CAMPUS NORTE  RELEVANTES
# 5    1176615  2023-07-14      MXP      EFECTIVO            RETIRO  00741513000118876274       171577   334300.00                      887 - CAMPUS NORTE  RELEVANTES
# 6    1176615  2023-07-18      MXP      EFECTIVO            RETIRO  00741513000118876274       213181   208000.00                      887 - CAMPUS NORTE  RELEVANTES
# 7    1176615  2023-07-18      MXP      EFECTIVO            RETIRO  00741513000118876274       213182   520000.00                      887 - CAMPUS NORTE  RELEVANTES
# 8    1176615  2023-07-07      MXP      EFECTIVO            RETIRO  00741513000118876274       082582   273300.00                      887 - CAMPUS NORTE  RELEVANTES
# 9    1176615  2023-07-21      MXP      EFECTIVO            RETIRO  00741513000118876274       262202   500000.00                      887 - CAMPUS NORTE  RELEVANTES
# 10   1176615  2023-07-31      MXP      EFECTIVO            RETIRO  00741513000118876274       376919   408000.00                      887 - CAMPUS NORTE  RELEVANTES
# 11   1176615  2023-07-28      MXP      EFECTIVO            RETIRO  00741513000118876274       354664   144000.00                      887 - CAMPUS NORTE  RELEVANTES
# 12   1176615  2023-08-01      MXP      EFECTIVO            RETIRO  00741513000118876274       003385   346000.00                      887 - CAMPUS NORTE  RELEVANTES
# 13   1176615  2023-08-04      MXP      EFECTIVO            RETIRO  00741513000118876274       057330   460000.00                      887 - CAMPUS NORTE  RELEVANTES
# 14   1176615  2023-08-25      MXP      EFECTIVO            RETIRO  00741513000118876274       320003   270000.00                      887 - CAMPUS NORTE  RELEVANTES
# 15   1176615  2023-08-15      MXP      EFECTIVO            RETIRO  00741513000118876274       185740   243140.00                      887 - CAMPUS NORTE  RELEVANTES
# 16   1176615  2023-08-18      MXP      EFECTIVO            RETIRO  00741513000118876274       232595   270000.00                      887 - CAMPUS NORTE  RELEVANTES
# 17   1176615  2023-08-18      MXP      EFECTIVO            RETIRO  00741513000118876274       232596   230850.00                      887 - CAMPUS NORTE  RELEVANTES
# 18   1176615  2023-08-31      MXP      EFECTIVO            RETIRO  00741513000118876274       396970   576574.00                      887 - CAMPUS NORTE  RELEVANTES
# 19   1176615  2023-08-31      MXP      EFECTIVO            RETIRO  00741513000118876274       396971   140000.00                      887 - CAMPUS NORTE  RELEVANTES
# 20   1176615  2023-08-29      MXP      EFECTIVO            RETIRO  00741513000118876274       361187   153000.00                      887 - CAMPUS NORTE  RELEVANTES
# 21   1176615  2023-09-01      MXP      EFECTIVO            RETIRO  00741513000118876274       005061   235000.00                      887 - CAMPUS NORTE  RELEVANTES
# 22   1176615  2023-09-01      MXP      EFECTIVO            RETIRO  00741513000118876274       005062   515000.00                      887 - CAMPUS NORTE  RELEVANTES
# 23   1176615  2023-09-08      MXP      EFECTIVO            RETIRO  00741513000118876274       096178   170000.00                      887 - CAMPUS NORTE  RELEVANTES
# 24   1176615  2023-09-08      MXP      EFECTIVO            RETIRO  00741513000118876274       096179   778017.00                      887 - CAMPUS NORTE  RELEVANTES
# 25   1176615  2023-09-12      MXP      EFECTIVO            RETIRO  00741513000118876274       134117   167670.00                      887 - CAMPUS NORTE  RELEVANTES
# 26   1176615  2023-09-15      MXP      EFECTIVO            RETIRO  00741513000118876274       180348   400000.00                      887 - CAMPUS NORTE  RELEVANTES
# 27   1176615  2023-09-29      MXP      EFECTIVO            RETIRO  00741513000118876274       350800   302000.00                      887 - CAMPUS NORTE  RELEVANTES
# 28   1176615  2023-10-17      MXP      EFECTIVO            RETIRO  00741513000118876274       190466   188400.00                      887 - CAMPUS NORTE  RELEVANTES
# 29   1176615  2023-10-13      MXP      EFECTIVO            RETIRO  00741513000118876274       151872   160000.00                      887 - CAMPUS NORTE  RELEVANTES
# 30   1176615  2023-10-06      MXP      EFECTIVO            RETIRO  00741513000118876274       073698   210000.00                      887 - CAMPUS NORTE  RELEVANTES
# 31   1176615  2023-10-03      MXP      EFECTIVO            RETIRO  00741513000118876274       026067   265600.00                      887 - CAMPUS NORTE  RELEVANTES
# 32   1176615  2023-11-03      MXP      EFECTIVO            RETIRO  00741513000118876274       021691   396100.00                      887 - CAMPUS NORTE  RELEVANTES
# 33   1176615  2023-11-07      MXP      EFECTIVO            RETIRO  00741513000118876274       068002   350000.00                      887 - CAMPUS NORTE  RELEVANTES
# 34   1176615  2023-10-31      MXP      EFECTIVO            RETIRO  00741513000118876274       354172   255000.00                      887 - CAMPUS NORTE  RELEVANTES
# 35   1176615  2023-11-01      MXP      EFECTIVO            RETIRO  00741513000118876274       004277   353255.00                      887 - CAMPUS NORTE  RELEVANTES
# 36   1176615  2023-10-27      MXP      EFECTIVO            RETIRO  00741513000118876274       314680   200000.00                      887 - CAMPUS NORTE  RELEVANTES
# 37   1176615  2023-10-24      MXP      EFECTIVO            RETIRO  00741513000118876274       270114   217800.00                      887 - CAMPUS NORTE  RELEVANTES
# 38   1176615  2023-11-30      MXP      EFECTIVO            RETIRO  00741513000118876274       374606   160000.00                      887 - CAMPUS NORTE  RELEVANTES
# 39   1176615  2023-12-14      MXP      EFECTIVO            RETIRO  00741513000118876274       178503   273000.00                      887 - CAMPUS NORTE  RELEVANTES
# 40   1176615  2023-12-20      MXP      EFECTIVO            RETIRO  00741513000118876274       272754   411000.00                      887 - CAMPUS NORTE  RELEVANTES
# 41   1176615  2024-01-02      MXP      EFECTIVO            RETIRO  00741513000118876274       003313   373600.00                      887 - CAMPUS NORTE  RELEVANTES
# 42   1176615  2024-01-02      MXP      EFECTIVO            RETIRO  00741513000118876274       003315   600000.00                      887 - CAMPUS NORTE  RELEVANTES
# 43   1176615  2024-01-02      MXP      EFECTIVO            RETIRO  00741513000118876274       003316   750000.00                      887 - CAMPUS NORTE  RELEVANTES
# 44   1176615  2024-01-12      MXP      EFECTIVO            RETIRO  00741513000118876274       181428   150000.00                      887 - CAMPUS NORTE  RELEVANTES
# 45   1176615  2024-01-30      MXP      EFECTIVO            RETIRO  00741513000118876274       416204   238780.00                      887 - CAMPUS NORTE  RELEVANTES
# 46   1176615  2024-01-19      MXP      EFECTIVO            RETIRO  00741513000118876274       278573   200000.00                      887 - CAMPUS NORTE  RELEVANTES
# 47   1176615  2024-01-17      MXP      EFECTIVO            RETIRO  00741513000118876274       244034   237800.00                      887 - CAMPUS NORTE  RELEVANTES
# 48   1176615  2024-01-24      MXP      EFECTIVO            RETIRO  00741513000118876274       339430   300000.00                      887 - CAMPUS NORTE  RELEVANTES
# 49   1176615  2024-02-07      MXP      EFECTIVO            RETIRO  00741513000118876274       076864   515350.00                      887 - CAMPUS NORTE  RELEVANTES
# 50   1176615  2024-02-02      MXP      EFECTIVO            RETIRO  00741513000118876274       024257   666700.00                      887 - CAMPUS NORTE  RELEVANTES
# 51   1176615  2024-02-01      MXP      EFECTIVO            RETIRO  00741513000118876274       005505   700000.00                5036 - CHIHUAHUA SAUCITO  RELEVANTES
# 52   1176615  2024-01-26      MXP      EFECTIVO            RETIRO  00741513000118876274       372872   250000.00                      887 - CAMPUS NORTE  RELEVANTES
# 53   1176615  2024-02-23      MXP      EFECTIVO            RETIRO  00741513000118876274       303264   441200.00                      887 - CAMPUS NORTE  RELEVANTES
# 54   1176615  2024-02-21      MXP      EFECTIVO            RETIRO  00741513000118876274       269278   293650.00                      887 - CAMPUS NORTE  RELEVANTES
# 55   1176615  2024-02-15      MXP      EFECTIVO            RETIRO  00741513000118876274       192416   288000.00                      887 - CAMPUS NORTE  RELEVANTES
# 56   1176615  2024-02-15      MXP      EFECTIVO            RETIRO  00741513000118876274       192417   240000.00                      887 - CAMPUS NORTE  RELEVANTES
# 57   1176615  2024-02-09      MXP      EFECTIVO            RETIRO  00741513000118876274       114955   240000.00                      887 - CAMPUS NORTE  RELEVANTES
# 58   1176615  2024-03-11      MXP      EFECTIVO            RETIRO  00741513000118876274       127493   559980.00                      887 - CAMPUS NORTE  RELEVANTES
# 59   1176615  2024-03-08      MXP      EFECTIVO            RETIRO  00741513000118876274       106245   270000.00                      887 - CAMPUS NORTE  RELEVANTES
# 60   1176615  2024-03-05      MXP      EFECTIVO            RETIRO  00741513000118876274       051202   400000.00                      887 - CAMPUS NORTE  RELEVANTES
# 61   1176615  2024-03-04      MXP      EFECTIVO            RETIRO  00741513000118876274       026149   846280.00                      887 - CAMPUS NORTE  RELEVANTES
# 62   1176615  2024-02-27      MXP      EFECTIVO            RETIRO  00741513000118876274       345455   400000.00                      887 - CAMPUS NORTE  RELEVANTES
# 63   1176615  2024-02-28      MXP      EFECTIVO            RETIRO  00741513000118876274       365008   500000.00                      887 - CAMPUS NORTE  RELEVANTES
# 64   1176615  2024-02-28      MXP      EFECTIVO            RETIRO  00741513000118876274       365009   350200.00                      887 - CAMPUS NORTE  RELEVANTES
# 65   1176615  2024-03-26      MXP      EFECTIVO            RETIRO  00741513000118876274       341474   175000.00                      887 - CAMPUS NORTE  RELEVANTES
# 66   1176615  2024-04-01      MXP      EFECTIVO            RETIRO  00741513000118876274       003679   700000.00                      887 - CAMPUS NORTE  RELEVANTES
# 67   1176615  2024-03-27      MXP      EFECTIVO            RETIRO  00741513000118876274       363395   716500.00                      887 - CAMPUS NORTE  RELEVANTES
# 68   1176615  2024-03-27      MXP      EFECTIVO            RETIRO  00741513000118876274       363396   224400.00                      887 - CAMPUS NORTE  RELEVANTES
# 69   1176615  2024-04-04      MXP      EFECTIVO            RETIRO  00741513000118876274       080035   450000.00                      887 - CAMPUS NORTE  RELEVANTES
# 70   1176615  2024-04-11      MXP      EFECTIVO            RETIRO  00741513000118876274       176990   250000.00                      887 - CAMPUS NORTE  RELEVANTES
# 71   1176615  2024-04-12      MXP      EFECTIVO            RETIRO  00741513000118876274       194978   150000.00                      887 - CAMPUS NORTE  RELEVANTES
# 72   1176615  2024-04-19      MXP      EFECTIVO            RETIRO  00741513000118876274       288658   628000.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 73   1176615  2024-04-23      MXP      EFECTIVO            RETIRO  00741513000118876274       330744   200000.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 74   1176615  2024-05-03      MXP      EFECTIVO            RETIRO  00741513000118876274       029447   255680.00                      377 - CIUDAD ACU#A  RELEVANTES
# 75   1176615  2024-05-02      MXP      EFECTIVO            RETIRO  00741513000118876274       005906   684100.00                      887 - CAMPUS NORTE  RELEVANTES
# 76   1176615  2024-05-02      MXP      EFECTIVO            RETIRO  00741513000118876274       005907   650000.00                      887 - CAMPUS NORTE  RELEVANTES
# 77   1176615  2024-05-08      MXP      EFECTIVO            RETIRO  00741513000118876274       096044   250000.00                      887 - CAMPUS NORTE  RELEVANTES
# 78   1176615  2024-05-10      MXP      EFECTIVO            RETIRO  00741513000118876274       128949   660840.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 79   1176615  2024-05-23      MXP      EFECTIVO            RETIRO  00741513000118876274       299524   329000.00                      377 - CIUDAD ACU#A  RELEVANTES
# 80   1176615  2024-05-21      MXP      EFECTIVO            RETIRO  00741513000118876274       264578   390000.00                      887 - CAMPUS NORTE  RELEVANTES
# 81   1176615  2024-05-17      MXP      EFECTIVO            RETIRO  00741513000118876274       220945   456840.00                      377 - CIUDAD ACU#A  RELEVANTES
# 82   1176615  2024-05-27      MXP      EFECTIVO            RETIRO  00741513000118876274       336059   351480.00                      887 - CAMPUS NORTE  RELEVANTES
# 83   1176615  2024-05-24      MXP      EFECTIVO            RETIRO  00741513000118876274       316294   150000.00                      887 - CAMPUS NORTE  RELEVANTES
# 84   1176615  2024-05-28      MXP      EFECTIVO            RETIRO  00741513000118876274       358292   310600.00                      887 - CAMPUS NORTE  RELEVANTES
# 85   1176615  2024-06-07      MXP      EFECTIVO            RETIRO  00741513000118876274       081796   337650.00                      887 - CAMPUS NORTE  RELEVANTES
# 86   1176615  2024-06-03      MXP      EFECTIVO            RETIRO  00741513000118876274       011528   531000.00                      887 - CAMPUS NORTE  RELEVANTES
# 87   1176615  2024-06-01      MXP      EFECTIVO            RETIRO  00741513000118876274       000843   523500.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 88   1176615  2024-06-01      MXP      EFECTIVO            RETIRO  00741513000118876274       000844   500000.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 89   1176615  2024-06-04      MXP      EFECTIVO            RETIRO  00741513000118876274       030938   191100.00                      887 - CAMPUS NORTE  RELEVANTES
# 90   1176615  2024-06-14      MXP      EFECTIVO            RETIRO  00741513000118876274       167209   522500.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 91   1176615  2024-06-17      MXP      EFECTIVO            RETIRO  00741513000118876274       183947   195844.00                      377 - CIUDAD ACU#A  RELEVANTES
# 92   1176615  2024-06-19      MXP      EFECTIVO            RETIRO  00741513000118876274       220026   709600.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 93   1176615  2024-06-19      MXP      EFECTIVO            RETIRO  00741513000118876274       220027   641590.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 94   1176615  2024-06-11      MXP      EFECTIVO            RETIRO  00741513000118876274       121896   310290.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 95   1176615  2024-06-10      MXP      EFECTIVO            RETIRO  00741513000118876274       104704   640000.00                      887 - CAMPUS NORTE  RELEVANTES
# 96   1176615  2024-06-26      MXP      EFECTIVO            RETIRO  00741513000118876274       301860   145500.80          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 97   1176615  2024-06-20      MXP      EFECTIVO            RETIRO  00741513000118876274       234606   740000.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 98   1176615  2024-06-21      MXP      EFECTIVO            RETIRO  00741513000118876274       249068   250000.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 99   1176615  2024-07-01      MXP      EFECTIVO            RETIRO  00741513000118876274       004551   150000.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 100  1176615  2024-06-27      MXP      EFECTIVO            RETIRO  00741513000118876274       317383   224960.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 101  1176615  2024-07-18      MXP      EFECTIVO            RETIRO  00741513000118876274       227707   350000.00                      377 - CIUDAD ACU#A  RELEVANTES
# 102  1176615  2024-07-08      MXP      EFECTIVO            RETIRO  00741513000118876274       089733   409355.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 103  1176615  2024-07-09      MXP      EFECTIVO            RETIRO  00741513000118876274       111308   300000.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 104  1176615  2024-07-25      MXP      EFECTIVO            RETIRO  00741513000118876274       312861   188800.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 105  1176615  2024-07-19      MXP      EFECTIVO            RETIRO  00741513000118876274       242784   325100.00                      377 - CIUDAD ACU#A  RELEVANTES
# 106  1176615  2024-07-19      MXP      EFECTIVO            RETIRO  00741513000118876274       242785   371360.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 107  1176615  2024-07-23      MXP      EFECTIVO            RETIRO  00741513000118876274       282639   335000.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 108  1176615  2024-07-22      MXP      EFECTIVO            RETIRO  00741513000118876274       262235   205000.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 109  1176615  2024-08-01      MXP      EFECTIVO            RETIRO  00741513000118876274       003902   253800.00                      377 - CIUDAD ACU#A  RELEVANTES
# 110  1176615  2024-07-26      MXP      EFECTIVO            RETIRO  00741513000118876274       327464   300000.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 111  1176615  2024-07-26      MXP      EFECTIVO            RETIRO  00741513000118876274       327465   624000.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 112  1176615  2024-07-30      MXP      EFECTIVO            RETIRO  00741513000118876274       365689   206400.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 113  1176615  2024-08-09      MXP      EFECTIVO            RETIRO  00741513000118876274       101124   203970.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 114  1176615  2024-08-09      MXP      EFECTIVO            RETIRO  00741513000118876274       101125   280000.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 115  1176615  2024-08-12      MXP      EFECTIVO            RETIRO  00741513000118876274       123811   350000.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 116  1176615  2024-08-12      MXP      EFECTIVO            RETIRO  00741513000118876274       123812   156000.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 117  1176615  2024-08-26      MXP      EFECTIVO            RETIRO  00741513000118876274       273952   220000.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 118  1176615  2024-08-23      MXP      EFECTIVO            RETIRO  00741513000118876274       257945   200000.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 119  1176615  2024-08-23      MXP      EFECTIVO            RETIRO  00741513000118876274       257946   200000.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 120  1176615  2024-08-13      MXP      EFECTIVO            RETIRO  00741513000118876274       135832   150000.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 121  1176615  2024-08-27      MXP      EFECTIVO            RETIRO  00741513000118876274       293046   200000.00             271 - CHIHUAHUA UNIVERSIDAD  RELEVANTES
# 122  1176615  2024-08-27      MXP      EFECTIVO            RETIRO  00741513000118876274       293047   450000.00             271 - CHIHUAHUA UNIVERSIDAD  RELEVANTES
# 123  1176615  2024-08-27      MXP      EFECTIVO            RETIRO  00741513000118876274       293048   250000.00             271 - CHIHUAHUA UNIVERSIDAD  RELEVANTES
# 124  1176615  2024-08-28      MXP      EFECTIVO            RETIRO  00741513000118876274       308274   207650.00             271 - CHIHUAHUA UNIVERSIDAD  RELEVANTES
# 125  1176615  2024-08-28      MXP      EFECTIVO            RETIRO  00741513000118876274       308275   200000.00             271 - CHIHUAHUA UNIVERSIDAD  RELEVANTES
# 126  1176615  2024-09-10      MXP      EFECTIVO            RETIRO  00741513000118876274       098478   250000.00          355 - CHIHUAHUA PLAZA VALLARTA  RELEVANTES
# 127  1176615  2024-09-18      MXP      EFECTIVO            RETIRO  00741513000118876274       176734   300000.00             271 - CHIHUAHUA UNIVERSIDAD  RELEVANTES
# 128  1176615  2024-09-19      MXP      EFECTIVO            RETIRO  00741513000118876274       191625   350000.00                5036 - CHIHUAHUA SAUCITO  RELEVANTES
# 129  1176615  2024-09-19      MXP      EFECTIVO            RETIRO  00741513000118876274       191626   300000.00                5036 - CHIHUAHUA SAUCITO  RELEVANTES
# 130  1176615  2024-09-20      MXP      EFECTIVO            RETIRO  00741513000118876274       206366   430000.00             271 - CHIHUAHUA UNIVERSIDAD  RELEVANTES
# 131  1176615  2024-08-30      MXP      EFECTIVO            RETIRO  00741513000118876274       337261   300000.00             271 - CHIHUAHUA UNIVERSIDAD  RELEVANTES
# 132  1176615  2024-08-30      MXP      EFECTIVO            RETIRO  00741513000118876274       337262   300000.00             271 - CHIHUAHUA UNIVERSIDAD  RELEVANTES
# 133  1176615  2024-08-30      MXP      EFECTIVO            RETIRO  00741513000118876274       337263   312260.00             271 - CHIHUAHUA UNIVERSIDAD  RELEVANTES
# 134  1176615  2024-09-13      MXP      EFECTIVO            RETIRO  00741513000118876274       137496   167350.00             271 - CHIHUAHUA UNIVERSIDAD  RELEVANTES
# 135  1176615  2024-09-12      MXP      EFECTIVO            RETIRO  00741513000118876274       124982   355500.00             271 - CHIHUAHUA UNIVERSIDAD  RELEVANTES
# 136  1176615  2024-09-02      MXP      EFECTIVO            RETIRO  00741513000118876274       004353   389469.00             271 - CHIHUAHUA UNIVERSIDAD  RELEVANTES
# 137  1176615  2024-09-02      MXP      EFECTIVO            RETIRO  00741513000118876274       004354   350000.00             271 - CHIHUAHUA UNIVERSIDAD  RELEVANTES
# 138  1176615  2024-09-04      MXP      EFECTIVO            RETIRO  00741513000118876274       038412   305000.00             271 - CHIHUAHUA UNIVERSIDAD  RELEVANTES
# 139  1176615  2024-09-03      MXP      EFECTIVO            RETIRO  00741513000118876274       022663   250000.00             271 - CHIHUAHUA UNIVERSIDAD  RELEVANTES
# 140  1176615  2024-09-03      MXP      EFECTIVO            RETIRO  00741513000118876274       022664   250000.00             271 - CHIHUAHUA UNIVERSIDAD  RELEVANTES
# 141  1176615  2024-09-27      MXP      EFECTIVO            RETIRO  00741513000118876274       285012   180000.00             271 - CHIHUAHUA UNIVERSIDAD  RELEVANTES
# 142  1176615  2024-10-02      MXP      EFECTIVO            RETIRO  00741513000118876274       004550   905100.00             271 - CHIHUAHUA UNIVERSIDAD  RELEVANTES
# 143  1176615  2024-09-24      MXP      EFECTIVO            RETIRO  00741513000118876274       242553   400000.00             271 - CHIHUAHUA UNIVERSIDAD  RELEVANTES
# 144  1176615  2024-09-24      MXP      EFECTIVO            RETIRO  00741513000118876274       242554   180000.00             271 - CHIHUAHUA UNIVERSIDAD  RELEVANTES
# 145  1176615  2024-12-28      MXP      EFECTIVO            RETIRO  00741513000118876274       319321   496130.00                      377 - CIUDAD ACU#A  RELEVANTES
# 146  1176615  2024-12-31      MXP      EFECTIVO            RETIRO  00741513000118876274       350107   200000.00                      377 - CIUDAD ACU#A  RELEVANTES
# 147  1197600  2023-11-14      MXP      EFECTIVO            RETIRO  00745765000120584754       157010   150000.00            5762 - CANCUN PLAZA PORTALES  RELEVANTES
# 148  1197600  2023-11-10      MXP      EFECTIVO            RETIRO  00745765000120584754       117443   400000.00            5762 - CANCUN PLAZA PORTALES  RELEVANTES
# 149  1197600  2023-12-15      MXP      EFECTIVO            RETIRO  00745765000120584754       201667   800000.00            5762 - CANCUN PLAZA PORTALES  RELEVANTES
# 150  1197600  2023-12-15      MXP      EFECTIVO            RETIRO  00745765000120584754       201666   400000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 151  1197600  2024-09-10      MXP      EFECTIVO            RETIRO  00745765000120584754       098852   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 152  1197600  2024-09-10      MXP      EFECTIVO            RETIRO  00745765000120584754       098853   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 153  1197600  2024-09-06      MXP      EFECTIVO            RETIRO  00745765000120584754       065980   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 154  1197600  2024-09-06      MXP      EFECTIVO            RETIRO  00745765000120584754       065981   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 155  1197600  2024-09-18      MXP      EFECTIVO            RETIRO  00745765000120584754       177044   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 156  1197600  2024-09-18      MXP      EFECTIVO            RETIRO  00745765000120584754       177045   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 157  1197600  2024-09-18      MXP      EFECTIVO            RETIRO  00745765000120584754       177046   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 158  1197600  2024-09-18      MXP      EFECTIVO            RETIRO  00745765000120584754       177047   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 159  1197600  2024-09-20      MXP      EFECTIVO            RETIRO  00745765000120584754       206783   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 160  1197600  2024-09-20      MXP      EFECTIVO            RETIRO  00745765000120584754       206784   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 161  1197600  2024-09-20      MXP      EFECTIVO            RETIRO  00745765000120584754       206785   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 162  1197600  2024-09-20      MXP      EFECTIVO            RETIRO  00745765000120584754       206786   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 163  1197600  2024-09-20      MXP      EFECTIVO            RETIRO  00745765000120584754       206787   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 164  1197600  2024-09-20      MXP      EFECTIVO            RETIRO  00745765000120584754       206788   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 165  1197600  2024-09-13      MXP      EFECTIVO            RETIRO  00745765000120584754       137947   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 166  1197600  2024-09-13      MXP      EFECTIVO            RETIRO  00745765000120584754       137948   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 167  1197600  2024-09-17      MXP      EFECTIVO            RETIRO  00745765000120584754       154218   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 168  1197600  2024-09-17      MXP      EFECTIVO            RETIRO  00745765000120584754       154219   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 169  1197600  2024-09-04      MXP      EFECTIVO            RETIRO  00745765000120584754       038757   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 170  1197600  2024-09-04      MXP      EFECTIVO            RETIRO  00745765000120584754       038758   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 171  1197600  2024-09-04      MXP      EFECTIVO            RETIRO  00745765000120584754       038759   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 172  1197600  2024-09-27      MXP      EFECTIVO            RETIRO  00745765000120584754       285504   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 173  1197600  2024-09-27      MXP      EFECTIVO            RETIRO  00745765000120584754       285505   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 174  1197600  2024-09-27      MXP      EFECTIVO            RETIRO  00745765000120584754       285506   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 175  1197600  2024-09-27      MXP      EFECTIVO            RETIRO  00745765000120584754       285507   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 176  1197600  2024-10-10      MXP      EFECTIVO            RETIRO  00745765000120584754       104429   800000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 177  1197600  2024-10-04      MXP      EFECTIVO            RETIRO  00745765000120584754       041851   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 178  1197600  2024-10-04      MXP      EFECTIVO            RETIRO  00745765000120584754       041852   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 179  1197600  2024-10-04      MXP      EFECTIVO            RETIRO  00745765000120584754       041853   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 180  1197600  2024-10-04      MXP      EFECTIVO            RETIRO  00745765000120584754       041854   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 181  1197600  2024-09-24      MXP      EFECTIVO            RETIRO  00745765000120584754       242934   400000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 182  1197600  2024-09-24      MXP      EFECTIVO            RETIRO  00745765000120584754       242935   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 183  1197600  2024-09-24      MXP      EFECTIVO            RETIRO  00745765000120584754       242936   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 184  1197600  2024-10-11      MXP      EFECTIVO            RETIRO  00745765000120584754       117728   900000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 185  1197600  2024-10-11      MXP      EFECTIVO            RETIRO  00745765000120584754       117729   800000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 186  1197600  2024-10-11      MXP      EFECTIVO            RETIRO  00745765000120584754       117730   800000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 187  1197600  2024-11-08      MXP      EFECTIVO            RETIRO  00745765000120584754       071706   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 188  1197600  2024-11-08      MXP      EFECTIVO            RETIRO  00745765000120584754       071707   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 189  1197600  2024-11-04      MXP      EFECTIVO            RETIRO  00745765000120584754       016826   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 190  1197600  2024-11-15      MXP      EFECTIVO            RETIRO  00745765000120584754       143314   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 191  1197600  2024-11-15      MXP      EFECTIVO            RETIRO  00745765000120584754       143315   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 192  1197600  2024-11-15      MXP      EFECTIVO            RETIRO  00745765000120584754       143316   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 193  1197600  2024-11-15      MXP      EFECTIVO            RETIRO  00745765000120584754       143317   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 194  1197600  2024-11-29      MXP      EFECTIVO            RETIRO  00745765000120584754       288310   600000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 195  1197600  2024-11-22      MXP      EFECTIVO            RETIRO  00745765000120584754       212083   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 196  1197600  2024-11-22      MXP      EFECTIVO            RETIRO  00745765000120584754       212084   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 197  1197600  2024-12-06      MXP      EFECTIVO            RETIRO  00745765000120584754       065559   200000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 198  1197600  2024-12-06      MXP      EFECTIVO            RETIRO  00745765000120584754       065560   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 199  1197600  2024-12-13      MXP      EFECTIVO            RETIRO  00745765000120584754       132590   700000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 200  1197600  2024-12-20      MXP      EFECTIVO            RETIRO  00745765000120584754       228371   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 201  1197600  2024-12-20      MXP      EFECTIVO            RETIRO  00745765000120584754       228372   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 202  1197600  2025-01-17      MXP      EFECTIVO            RETIRO  00745765000120584754       174372   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 203  1197600  2025-01-17      MXP      EFECTIVO            RETIRO  00745765000120584754       174373   400000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 204  1197600  2025-01-24      MXP      EFECTIVO            RETIRO  00745765000120584754       247063   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 205  1197600  2025-01-31      MXP      EFECTIVO            RETIRO  00745765000120584754       322353   800000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 206  1197600  2025-02-07      MXP      EFECTIVO            RETIRO  00745765000120584754       060387   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 207  1197600  2025-02-28      MXP      EFECTIVO            RETIRO  00745765000120584754       273128   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 208  1197600  2025-02-28      MXP      EFECTIVO            RETIRO  00745765000120584754       273129   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 209  1197600  2025-02-21      MXP      EFECTIVO            RETIRO  00745765000120584754       201242   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 210  1197600  2025-02-21      MXP      EFECTIVO            RETIRO  00745765000120584754       201243   500000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL  RELEVANTES
# 211  1176615  2025-01-27      MXP      EFECTIVO            RETIRO  00741513000118876274      0628307   116400.00             271 - CHIHUAHUA UNIVERSIDAD    MEDIANAS
# 212  1176615  2025-01-22      MXP      EFECTIVO            RETIRO  00741513000118876274      0506383   148960.00             271 - CHIHUAHUA UNIVERSIDAD    MEDIANAS
# 213  1176615  2024-12-10      MXP      EFECTIVO            RETIRO  00741513000118876274      1168140   150000.00             271 - CHIHUAHUA UNIVERSIDAD    MEDIANAS
# 214  1176615  2024-12-24      MXP      EFECTIVO            RETIRO  00741513000118876274      1166597   147200.00                      377 - CIUDAD ACU#A    MEDIANAS
# 215  1176615  2024-10-12      MXP      EFECTIVO            RETIRO  00741513000118876274      0441530   120000.00                      377 - CIUDAD ACU#A    MEDIANAS
# 216  1176615  2024-10-04      MXP      EFECTIVO            RETIRO  00741513000118876274      0605141    97000.00             271 - CHIHUAHUA UNIVERSIDAD    MEDIANAS
# 217  1176615  2024-09-03      MXP      EFECTIVO            RETIRO  00741513000118876274      1626600    70000.00             271 - CHIHUAHUA UNIVERSIDAD    MEDIANAS
# 218  1176615  2024-09-23      MXP      EFECTIVO            RETIRO  00741513000118876274      0712144   100000.00                5036 - CHIHUAHUA SAUCITO    MEDIANAS
# 219  1176615  2024-09-06      MXP      EFECTIVO            RETIRO  00741513000118876274      0555957   103300.00             271 - CHIHUAHUA UNIVERSIDAD    MEDIANAS
# 220  1176615  2024-08-01      MXP      EFECTIVO            RETIRO  00741513000118876274      0654691    30000.00          355 - CHIHUAHUA PLAZA VALLARTA    MEDIANAS
# 221  1176615  2024-08-13      MXP      EFECTIVO            RETIRO  00741513000118876274      1230098   100000.00          355 - CHIHUAHUA PLAZA VALLARTA    MEDIANAS
# 222  1176615  2024-08-26      MXP      EFECTIVO            RETIRO  00741513000118876274      0665406   116400.00          355 - CHIHUAHUA PLAZA VALLARTA    MEDIANAS
# 223  1176615  2024-08-13      MXP      EFECTIVO            RETIRO  00741513000118876274      1230097    20942.00          355 - CHIHUAHUA PLAZA VALLARTA    MEDIANAS
# 224  1176615  2024-08-21      MXP      EFECTIVO            RETIRO  00741513000118876274      0575251   130000.00          355 - CHIHUAHUA PLAZA VALLARTA    MEDIANAS
# 225  1176615  2024-08-23      MXP      EFECTIVO            RETIRO  00741513000118876274      0509943   110000.00          355 - CHIHUAHUA PLAZA VALLARTA    MEDIANAS
# 226  1176615  2024-08-27      MXP      EFECTIVO            RETIRO  00741513000118876274      1214118   100000.00             271 - CHIHUAHUA UNIVERSIDAD    MEDIANAS
# 227  1176615  2024-08-21      MXP      EFECTIVO            RETIRO  00741513000118876274      0575250   100000.00          355 - CHIHUAHUA PLAZA VALLARTA    MEDIANAS
# 228  1176615  2024-08-20      MXP      EFECTIVO            RETIRO  00741513000118876274      1325404   102270.00          355 - CHIHUAHUA PLAZA VALLARTA    MEDIANAS
# 229  1176615  2024-08-28      MXP      EFECTIVO            RETIRO  00741513000118876274      0521078   140620.00             271 - CHIHUAHUA UNIVERSIDAD    MEDIANAS
# 230  1176615  2024-07-02      MXP      EFECTIVO            RETIRO  00741513000118876274      1627876    77980.00          355 - CHIHUAHUA PLAZA VALLARTA    MEDIANAS
# 231  1176615  2024-07-23      MXP      EFECTIVO          DEPOSITO  00741513000118876274      1262212     2400.00          355 - CHIHUAHUA PLAZA VALLARTA    MEDIANAS
# 232  1176615  2024-07-03      MXP      EFECTIVO            RETIRO  00741513000118876274      0683821    26500.00          355 - CHIHUAHUA PLAZA VALLARTA    MEDIANAS
# 233  1176615  2024-07-30      MXP      EFECTIVO            RETIRO  00741513000118876274      1238648    50000.00                      377 - CIUDAD ACU#A    MEDIANAS
# 234  1176615  2024-07-23      MXP      EFECTIVO            RETIRO  00741513000118876274      1262211    85000.00          355 - CHIHUAHUA PLAZA VALLARTA    MEDIANAS
# 235  1176615  2024-07-04      MXP      EFECTIVO            RETIRO  00741513000118876274      0618285   102290.00          355 - CHIHUAHUA PLAZA VALLARTA    MEDIANAS
# 236  1176615  2024-07-08      MXP      EFECTIVO            RETIRO  00741513000118876274      0737733    30000.00          355 - CHIHUAHUA PLAZA VALLARTA    MEDIANAS
# 237  1176615  2024-07-17      MXP      EFECTIVO            RETIRO  00741513000118876274      0679920   100000.00          355 - CHIHUAHUA PLAZA VALLARTA    MEDIANAS
# 238  1176615  2024-06-18      MXP      EFECTIVO            RETIRO  00741513000118876274      1446813    82650.00          355 - CHIHUAHUA PLAZA VALLARTA    MEDIANAS
# 239  1176615  2024-06-10      MXP      EFECTIVO            RETIRO  00741513000118876274      0722429   125000.00                      377 - CIUDAD ACU#A    MEDIANAS
# 240  1176615  2024-06-15      MXP      EFECTIVO            RETIRO  00741513000118876274      0518424    50000.00                      377 - CIUDAD ACU#A    MEDIANAS
# 241  1176615  2024-05-20      MXP      EFECTIVO            RETIRO  00741513000118876274      0815371    90000.00                      377 - CIUDAD ACU#A    MEDIANAS
# 242  1176615  2024-05-03      MXP      EFECTIVO            RETIRO  00741513000118876274      1219809    48000.00                      887 - CAMPUS NORTE    MEDIANAS
# 243  1176615  2024-05-07      MXP      EFECTIVO            RETIRO  00741513000118876274      1477862    96915.00                      887 - CAMPUS NORTE    MEDIANAS
# 244  1176615  2024-05-13      MXP      EFECTIVO            RETIRO  00741513000118876274      0655447    50000.00          355 - CHIHUAHUA PLAZA VALLARTA    MEDIANAS
# 245  1176615  2024-04-19      MXP      EFECTIVO            RETIRO  00741513000118876274      0543432    90000.00          355 - CHIHUAHUA PLAZA VALLARTA    MEDIANAS
# 246  1176615  2024-04-16      MXP      EFECTIVO            RETIRO  00741513000118876274      1443813   100000.00                      887 - CAMPUS NORTE    MEDIANAS
# 247  1176615  2024-04-24      MXP      EFECTIVO            RETIRO  00741513000118876274      0558599    85000.00          355 - CHIHUAHUA PLAZA VALLARTA    MEDIANAS
# 248  1176615  2024-04-18      MXP      EFECTIVO            RETIRO  00741513000118876274      0578605   100000.00                      887 - CAMPUS NORTE    MEDIANAS
# 249  1176615  2024-04-24      MXP      EFECTIVO            RETIRO  00741513000118876274      0558598   117320.00                      887 - CAMPUS NORTE    MEDIANAS
# 250  1176615  2024-03-22      MXP      EFECTIVO            RETIRO  00741513000118876274      0566814    70000.00                      887 - CAMPUS NORTE    MEDIANAS
# 251  1176615  2024-03-06      MXP      EFECTIVO            RETIRO  00741513000118876274      0667798    96000.00                      887 - CAMPUS NORTE    MEDIANAS
# 252  1176615  2024-02-01      MXP      EFECTIVO            RETIRO  00741513000118876274      0704856   118800.00                5036 - CHIHUAHUA SAUCITO    MEDIANAS
# 253  1176615  2024-02-15      MXP      EFECTIVO            RETIRO  00741513000118876274      0532664   100000.00                      887 - CAMPUS NORTE    MEDIANAS
# 254  1176615  2024-02-07      MXP      EFECTIVO            RETIRO  00741513000118876274      1927004    21200.00                      887 - CAMPUS NORTE    MEDIANAS
# 255  1180636  2025-02-10      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0681867    36552.00                        1899 - EL DORADO    MEDIANAS
# 256  1180636  2025-02-11      MXP      EFECTIVO            RETIRO  00747696000124019830      1149528     2000.00                        1899 - EL DORADO    MEDIANAS
# 257  1180636  2025-02-12      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0494330    14237.00                        1899 - EL DORADO    MEDIANAS
# 258  1180636  2025-02-06      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0563821     4757.00                        1899 - EL DORADO    MEDIANAS
# 259  1180636  2025-02-11      MXP      EFECTIVO          DEPOSITO  00747696000124019989      1149530    14451.00                        1899 - EL DORADO    MEDIANAS
# 260  1180636  2025-02-11      MXP      EFECTIVO          DEPOSITO  00747696000124019989      1149531      336.00                        1899 - EL DORADO    MEDIANAS
# 261  1180636  2025-02-05      MXP      EFECTIVO          DEPOSITO  00747696000124019989      1798967    11329.00                        1899 - EL DORADO    MEDIANAS
# 262  1180636  2025-02-10      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0681866    20638.00                        1899 - EL DORADO    MEDIANAS
# 263  1180636  2025-02-07      MXP      EFECTIVO          DEPOSITO  00747696610124019989      0745588      880.00                        1899 - EL DORADO    MEDIANAS
# 264  1180636  2025-02-11      MXP      EFECTIVO          DEPOSITO  00747696000124019989      1149529     3369.00                        1899 - EL DORADO    MEDIANAS
# 265  1180636  2025-02-12      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0494331    18459.00                        1899 - EL DORADO    MEDIANAS
# 266  1180636  2025-02-04      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0828353    22407.00                        1899 - EL DORADO    MEDIANAS
# 267  1180636  2025-02-06      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0563820    10225.00                        1899 - EL DORADO    MEDIANAS
# 268  1180636  2025-02-07      MXP      EFECTIVO          DEPOSITO  00747696610124019989      0745587    11594.00                        1899 - EL DORADO    MEDIANAS
# 269  1180636  2025-02-04      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0828352    16048.00                        1899 - EL DORADO    MEDIANAS
# 270  1180636  2025-02-05      MXP      EFECTIVO          DEPOSITO  00747696000124019989      1798968    20327.00                        1899 - EL DORADO    MEDIANAS
# 271  1180636  2025-02-07      MXP      EFECTIVO          DEPOSITO  00747696610124019989      0745589     1439.00                        1899 - EL DORADO    MEDIANAS
# 272  1180636  2025-01-28      MXP      EFECTIVO          DEPOSITO  00747696000124019989      1094584     5721.00                        1899 - EL DORADO    MEDIANAS
# 273  1180636  2025-01-06      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0734181    40559.00                        1899 - EL DORADO    MEDIANAS
# 274  1180636  2025-01-09      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0517528    15259.00                        1899 - EL DORADO    MEDIANAS
# 275  1180636  2025-01-15      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0545408    33843.00                        1899 - EL DORADO    MEDIANAS
# 276  1180636  2025-01-16      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0613641    32613.00                        1899 - EL DORADO    MEDIANAS
# 277  1180636  2025-01-16      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0613642    54083.00                        1899 - EL DORADO    MEDIANAS
# 278  1180636  2025-01-30      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0505660    13410.00                        1899 - EL DORADO    MEDIANAS
# 279  1180636  2025-01-03      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0738633    15866.00                        1899 - EL DORADO    MEDIANAS
# 280  1180636  2025-01-06      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0734180    46473.00                        1899 - EL DORADO    MEDIANAS
# 281  1180636  2025-01-22      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0521952    14027.00                        1899 - EL DORADO    MEDIANAS
# 282  1180636  2025-01-22      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0521954      266.00                        1899 - EL DORADO    MEDIANAS
# 283  1180636  2025-01-31      MXP      EFECTIVO            RETIRO  00747696000124019830      0562239    38000.00                        1899 - EL DORADO    MEDIANAS
# 284  1180636  2025-01-23      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0489119    11695.00                        1899 - EL DORADO    MEDIANAS
# 285  1180636  2025-01-13      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0683071    27584.00                        1899 - EL DORADO    MEDIANAS
# 286  1180636  2025-01-15      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0545409    11034.00                        1899 - EL DORADO    MEDIANAS
# 287  1180636  2025-01-28      MXP      EFECTIVO          DEPOSITO  00747696000124019989      1094586    11980.00                        1899 - EL DORADO    MEDIANAS
# 288  1180636  2025-01-29      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0504409    22364.00                        1899 - EL DORADO    MEDIANAS
# ...
# 381  1180636  2024-11-21      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0522002      150.00                        1899 - EL DORADO    MEDIANAS
# 382  1180636  2024-11-21      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0522005      100.00                        1899 - EL DORADO    MEDIANAS
# 383  1180636  2024-11-25      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0657330      300.00                        1899 - EL DORADO    MEDIANAS
# 384  1180636  2024-11-21      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0522006      200.00                        1899 - EL DORADO    MEDIANAS
# 385  1180636  2024-11-21      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0522000      450.00                        1899 - EL DORADO    MEDIANAS
# 386  1180636  2024-11-21      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0522008      200.00                        1899 - EL DORADO    MEDIANAS
# 387  1180636  2024-11-21      MXP      EFECTIVO          DEPOSITO  00747696000124019989      0522009      150.00                        1899 - EL DORADO    MEDIANAS
# 388  1185772  2025-02-13      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0237862     4000.00                         0 - NO DEFINIDO    MEDIANAS
# 389  1185772  2025-02-05      MXP      EFECTIVO          DEPOSITO  00744485082914964810      2007996     5500.00       4485 - MONTERREY CENTRO PRINCIPAL    MEDIANAS
# 390  1185772  2025-01-20      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0776142     4000.00                         0 - NO DEFINIDO    MEDIANAS
# 391  1185772  2025-01-15      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0361633     5000.00                         0 - NO DEFINIDO    MEDIANAS
# 392  1185772  2025-01-20      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0776143     5000.00                         0 - NO DEFINIDO    MEDIANAS
# 393  1185772  2025-01-15      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0361634     3000.00                         0 - NO DEFINIDO    MEDIANAS
# 394  1185772  2025-01-02      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0464977     2700.00                         0 - NO DEFINIDO    MEDIANAS
# 395  1185772  2025-01-28      MXP      EFECTIVO          DEPOSITO  00744485082914964810      1284107     6000.00       4485 - MONTERREY CENTRO PRINCIPAL    MEDIANAS
# 396  1185772  2024-12-27      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0287997     5000.00                         0 - NO DEFINIDO    MEDIANAS
# 397  1185772  2024-12-10      MXP      EFECTIVO          DEPOSITO  00744485082914964810      1415815    13600.00             5133 - PLAYACAR CENTRO MAYA    MEDIANAS
# 398  1185772  2024-12-11      MXP      EFECTIVO          DEPOSITO  00744485082914964810      0791201    10000.00       4485 - MONTERREY CENTRO PRINCIPAL    MEDIANAS
# 399  1185772  2024-12-16      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0928131     5000.00                         0 - NO DEFINIDO    MEDIANAS
# 400  1185772  2024-12-23      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0826213     3500.00                         0 - NO DEFINIDO    MEDIANAS
# 401  1185772  2024-11-12      MXP      EFECTIVO          DEPOSITO  00744485082914964810      1520636     2400.00              204 - MONTERREY REVOLUCION    MEDIANAS
# 402  1185772  2024-11-19      MXP      EFECTIVO          DEPOSITO  00744485002914964810      1177833     5000.00                         0 - NO DEFINIDO    MEDIANAS
# 403  1185772  2024-11-01      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0355588     2075.00                         0 - NO DEFINIDO    MEDIANAS
# 404  1185772  2024-11-04      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0871879     3500.00                         0 - NO DEFINIDO    MEDIANAS
# 405  1185772  2024-11-29      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0330516     5000.00                         0 - NO DEFINIDO    MEDIANAS
# 406  1185772  2024-11-06      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0304842     3000.00                         0 - NO DEFINIDO    MEDIANAS
# 407  1185772  2024-10-30      MXP      EFECTIVO          DEPOSITO  00744485082914964810      0769909     5000.00       4485 - MONTERREY CENTRO PRINCIPAL    MEDIANAS
# 408  1185772  2024-10-02      MXP      EFECTIVO          DEPOSITO  00744485082914964810      1717692     7550.00       4485 - MONTERREY CENTRO PRINCIPAL    MEDIANAS
# 409  1185772  2024-10-08      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0330854     5000.00                         0 - NO DEFINIDO    MEDIANAS
# 410  1185772  2024-10-07      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0938059     4000.00                 216 - MONTERREY COUNTRY    MEDIANAS
# 411  1185772  2024-10-28      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0808336     3500.00                 5076 - PLAZA SAN MARCOS    MEDIANAS
# 412  1185772  2024-10-28      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0808337     2400.00                         0 - NO DEFINIDO    MEDIANAS
# 413  1185772  2024-10-23      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0260858     5000.00                         0 - NO DEFINIDO    MEDIANAS
# 414  1185772  2024-10-15      MXP      EFECTIVO          DEPOSITO  00744485082914964810      1522099     6000.00       4485 - MONTERREY CENTRO PRINCIPAL    MEDIANAS
# 415  1185772  2024-09-13      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0345862     4000.00                         0 - NO DEFINIDO    MEDIANAS
# 416  1185772  2024-09-13      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0345863     5000.00                         0 - NO DEFINIDO    MEDIANAS
# 417  1185772  2024-08-01      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0437587     5000.00                         0 - NO DEFINIDO    MEDIANAS
# 418  1185772  2024-08-07      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0323536     5500.00                296 - MONTERREY SATELITE    MEDIANAS
# 419  1185772  2024-08-30      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0383592     5000.00                         0 - NO DEFINIDO    MEDIANAS
# 420  1185772  2024-08-13      MXP      EFECTIVO          DEPOSITO  00744485082914964810      1433598     9000.00       4485 - MONTERREY CENTRO PRINCIPAL    MEDIANAS
# 421  1185772  2024-08-21      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0313376     5000.00                         0 - NO DEFINIDO    MEDIANAS
# 422  1185772  2024-08-19      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0895364     2000.00                         0 - NO DEFINIDO    MEDIANAS
# 423  1185772  2024-07-05      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0359567     5000.00                         0 - NO DEFINIDO    MEDIANAS
# 424  1185772  2024-07-01      MXP      EFECTIVO          DEPOSITO  00744485002914964810      1145350     5000.00                         0 - NO DEFINIDO    MEDIANAS
# 425  1185772  2024-07-02      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0430311     4900.00                         0 - NO DEFINIDO    MEDIANAS
# 426  1185772  2024-07-12      MXP      EFECTIVO            RETIRO  00744485002914964810      0785210    18000.00                 216 - MONTERREY COUNTRY    MEDIANAS
# 427  1185772  2024-07-23      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0335905     4000.00                         0 - NO DEFINIDO    MEDIANAS
# 428  1185772  2024-07-23      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0335906     3500.00                 5076 - PLAZA SAN MARCOS    MEDIANAS
# 429  1185772  2024-07-08      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0918410     5000.00                        747 - LOMA LARGA    MEDIANAS
# 430  1185772  2024-07-16      MXP      EFECTIVO          DEPOSITO  00744485082914964810      1683180     7000.00       4485 - MONTERREY CENTRO PRINCIPAL    MEDIANAS
# 431  1185772  2024-06-03      MXP      EFECTIVO          DEPOSITO  00744485002914964810      1141668     4900.00                         0 - NO DEFINIDO    MEDIANAS
# 432  1185772  2024-06-17      MXP      EFECTIVO          DEPOSITO  00744485002914964810      1006339     5000.00                         0 - NO DEFINIDO    MEDIANAS
# 433  1185772  2024-06-12      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0302466     5000.00                         0 - NO DEFINIDO    MEDIANAS
# 434  1185772  2024-06-17      MXP      EFECTIVO          DEPOSITO  00744485002914964810      1006340     3900.00                 222 - MONTERREY CUMBRES    MEDIANAS
# 435  1185772  2024-06-12      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0302467     4900.00                         0 - NO DEFINIDO    MEDIANAS
# 436  1185772  2024-06-24      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0814323     2000.00                         0 - NO DEFINIDO    MEDIANAS
# 437  1185772  2024-06-25      MXP      EFECTIVO          DEPOSITO  00744485082914964810      1396625    13000.00         5299 - PLAZA FIESTA SAN AGUSTIN    MEDIANAS
# 438  1185772  2024-05-28      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0341075     4500.00          3769 - MONTERREY 2EVO REPUEBLO    MEDIANAS
# 439  1185772  2024-05-02      MXP      EFECTIVO          DEPOSITO  00744485082914964810      1032519     5500.00              4751 - PLAZA BELLA ANAHUAC    MEDIANAS
# 440  1185772  2024-05-23      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0304117     5000.00                         0 - NO DEFINIDO    MEDIANAS
# 441  1185772  2024-05-13      MXP      EFECTIVO          DEPOSITO  00744485082914964810      0882887    10000.00       4485 - MONTERREY CENTRO PRINCIPAL    MEDIANAS
# 442  1185772  2024-05-23      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0304118     5000.00                         0 - NO DEFINIDO    MEDIANAS
# 443  1185772  2024-05-17      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0381627     2000.00                 216 - MONTERREY COUNTRY    MEDIANAS
# 444  1185772  2024-05-31      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0433587     5000.00                         0 - NO DEFINIDO    MEDIANAS
# 445  1185772  2024-04-29      MXP      EFECTIVO          DEPOSITO  00744485082914964810      0969000    21500.00                    217 - ESCOBEDO GASCA    MEDIANAS
# 446  1185772  2024-04-16      MXP      EFECTIVO          DEPOSITO  00744485082914964810      1700979    10000.00       4485 - MONTERREY CENTRO PRINCIPAL    MEDIANAS
# 447  1185772  2024-04-30      MXP      EFECTIVO          DEPOSITO  00744485082914964810      1672183    10000.00       4485 - MONTERREY CENTRO PRINCIPAL    MEDIANAS
# 448  1185772  2024-04-04      MXP      EFECTIVO          DEPOSITO  00744485082914964810      0807405     8000.00       4485 - MONTERREY CENTRO PRINCIPAL    MEDIANAS
# 449  1185772  2024-04-25      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0296614     4900.00              204 - MONTERREY REVOLUCION    MEDIANAS
# 450  1185772  2024-03-14      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0331112     4500.00                296 - MONTERREY SATELITE    MEDIANAS
# 451  1185772  2024-03-25      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0881014     5000.00                         0 - NO DEFINIDO    MEDIANAS
# 452  1185772  2024-03-25      MXP      EFECTIVO            RETIRO  00744485082914964810      0974363    37800.00                 216 - MONTERREY COUNTRY    MEDIANAS
# 453  1185772  2024-03-25      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0881013     4900.00                    4777 - PLAZA VELARIA    MEDIANAS
# 454  1185772  2024-03-06      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0355748     5000.00                         0 - NO DEFINIDO    MEDIANAS
# 455  1185772  2024-03-01      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0459085     7000.00        1073 - CANCUN PLAZA LAS AMERICAS    MEDIANAS
# 456  1185772  2024-03-06      MXP      EFECTIVO          DEPOSITO  00744485002914964810      0355749     1900.00                         0 - NO DEFINIDO    MEDIANAS
# 457  1185772  2024-03-07      MXP      EFECTIVO          DEPOSITO  00744485082914964810      0788914     4900.00                   3775 - GUADALUPE EXPO    MEDIANAS
# 458  1185772  2024-03-15      MXP      EFECTIVO          DEPOSITO  00744485082914964810      0897594     6000.00       4485 - MONTERREY CENTRO PRINCIPAL    MEDIANAS
# 459  1197600  2024-12-20      MXP      EFECTIVO            RETIRO  00745765000120584754      0537926   100000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL    MEDIANAS
# 460  1197600  2024-09-13      MXP      EFECTIVO            RETIRO  00745765000120584754      0468631    40000.00                    2725 - PUERTO CANCUN    MEDIANAS
# 461  1197600  2024-08-23      MXP      EFECTIVO            RETIRO  00745765000120584754      0516328    49000.00                    2725 - PUERTO CANCUN    MEDIANAS
# 462  1197600  2024-08-02      MXP      EFECTIVO            RETIRO  00745765000120584754      0702431    50000.00            5762 - CANCUN PLAZA PORTALES    MEDIANAS
# 463  1197600  2024-08-30      MXP      EFECTIVO            RETIRO  00745765000120584754      0537510   126000.00  5765 - PLAYA DEL CARMEN OFNA PRINCIPAL    MEDIANAS
# 464  1197600  2024-07-26      MXP      EFECTIVO            RETIRO  00745765000120584754      0495650    45000.00            5762 - CANCUN PLAZA PORTALES    MEDIANAS
# 465  1197600  2024-07-12      MXP      EFECTIVO            RETIRO  00745765000120584754      0527893    19000.00            5762 - CANCUN PLAZA PORTALES    MEDIANAS
# 466  1197600  2024-07-19      MXP      EFECTIVO            RETIRO  00745765000120584754      0549604    49000.00            5762 - CANCUN PLAZA PORTALES    MEDIANAS
# 467  1198373  2025-03-12      MXP      EFECTIVO          DEPOSITO  00743607001529864740      0193062     3000.00                         0 - NO DEFINIDO    MEDIANAS
# 468  1198373  2025-03-11      MXP      EFECTIVO          DEPOSITO  00743607001529864740      1260526     3000.00          4455 - CHIHUAHUA JUAN PABLO II    MEDIANAS
# 469  1198373  2025-03-11      MXP      EFECTIVO          DEPOSITO  00743607001529864740      0207366     4000.00                         0 - NO DEFINIDO    MEDIANAS
# 470  1198373  2025-02-04      MXP      EFECTIVO          DEPOSITO  00743607001529864740      0853451     2250.00                         0 - NO DEFINIDO    MEDIANAS
# 471  1198373  2025-02-04      MXP      EFECTIVO          DEPOSITO  00743607001529864740      0853452     2500.00                         0 - NO DEFINIDO    MEDIANAS
# 472  1198373  2025-02-10      MXP      EFECTIVO          DEPOSITO  00743607001529864740      0526850     5000.00                         0 - NO DEFINIDO    MEDIANAS
# 473  1198373  2025-02-10      MXP      EFECTIVO          DEPOSITO  00743607001529864740      0526851     5000.00                         0 - NO DEFINIDO    MEDIANAS
# 474  1198373  2025-01-22      MXP      EFECTIVO          DEPOSITO  00743607001529864740      0190695     3000.00                         0 - NO DEFINIDO    MEDIANAS
# 475  1198373  2025-01-27      MXP      EFECTIVO          DEPOSITO  00743607001529864740      0493747     5000.00                         0 - NO DEFINIDO    MEDIANAS
# 476  1198373  2024-10-29      MXP      EFECTIVO          DEPOSITO  00743607691529864740      1375369      200.00                      6520 - CHICONTEPEC    MEDIANAS
#
# Guardando los resultados en un archivo Parquet...
# ¡Archivo 'resultados_consulta.parquet' guardado con éxito!

# %% [markdown]
# 013 se van a agregar 2 campos:
# - alerta
# - sistema

# %% [markdown]
# ## Consulta 6

# %%
mi_query6 = """
SELECT
  cdCaso,
  numCuenta,
  tpTransaccion,
  -- CAMBIO AQUÍ: Se reemplaza NVL por COALESCE
  COALESCE((SELECT NB_PAIS FROM TSCA106_PAIS WHERE CD_PAIS_UIF = cdPaisDestino),cdPaisDestino) AS cdPaisDestino,
  cdParaisoFiscal,
  nivelRiesgo,
  -- CAMBIO AQUÍ: Se reemplaza NVL por COALESCE
  COALESCE(COUNT( cdReferencia ),0) numOperaciones,
  COALESCE(SUM( imInstrumento ),0) montoTransacciones,
  fhFolio
FROM
(
  SELECT 
    T13.CD_CASO AS cdCaso,
    T60.CD_REFERENCIA cdReferencia,
    T60.NU_CUENTA numCuenta,
    T60.FH_REPORTE fhReporte,
    T60.CD_ORG_REGULADOR orgRegulador,
    T60.CD_ENTIDAD cdEntidad,
    TO_CHAR( T60.FH_FOLIO, 'YYYY' ) fhFolio,
    CASE T60.TP_TRANSACC 
        WHEN 'R' THEN 'RECIBIDAS' 
        WHEN 'E' THEN 'ENVIADAS' 
    END AS tpTransaccion,
    T60.NB_CORRESPONSAL nbCorresponsal,
    T60.NB_ENTIDAD_ORIGEN nbEntidadOrigen,
    T60.NB_ENTIDAD_DESTINO nbEntidadDestino,
    T60.CD_BIC_ABA cdBicAba,
    T60.NB_OPER_ORIGEN nbOperOrigen,
    T60.NB_OPER_DESTINO nbOperDest,
    T60.CD_INSTRUMENTO cdInstrumento,
    T60.NU_CLIENTE nuCliente,
    T60.CD_MONEDA cdMoneda,
    T60.IM_INST_CAMBIO imInstrumento,
    T60.CD_PAIS_ORI cdPaisOrigen,
    T60.CD_PAIS_BENEF cdPaisDestino,
    T69.NB_NIVEL_RIESGO nivelRiesgo,
    T69.CD_PARAISO_FISC cdParaisoFiscal,
    T60.FH_PROCESO anioProceso
  FROM TSCA060_OPIS T60
  JOIN TSCA013_ALERTA T13
    ON T13.CD_CASO = T60.CD_CASO  AND T13.CD_CLIENTE = T60.NU_CLIENTE
  LEFT JOIN TSCA069_RIESGO_PAIS T69
    ON T60.CD_PAIS_BENEF = T69.CD_ISO    
  WHERE
    T13.CD_CASO IN (&CD_CASO_LIST)
    AND T13.CD_SISTEMA IN (&CD_SISTEMA_LIST)
    AND T13.CD_ALERTA IN (&CD_ALERTA_LIST)
) AS subconsulta
GROUP BY cdCaso,numCuenta,tpTransaccion,nivelRiesgo,cdParaisoFiscal,cdPaisDestino,fhFolio
ORDER BY fhFolio asc;
"""

# %%
import re

query_in = mi_query6.replace("&CD_SISTEMA_LIST", CD_SISTEMA)\
    .replace("&CD_ALERTA_LIST", CD_ALERTA)\
    .replace("&CD_CASO_LIST", CD_CASO)

query_segura = re.sub(r'&\w+', '%s', query_in)

print("\nConectando a la base de datos y ejecutando la consulta...")
conn = psycopg2.connect(**db_connection_params)
cursor = conn.cursor()

cursor.execute(query_segura)

if cursor.rowcount == 0:
    print("\nLa consulta se ejecutó correctamente, pero no arrojó resultados.")

columnas = [desc[0] for desc in cursor.description]

registros = cursor.fetchall()

df = pd.DataFrame(registros, columns=columnas)

print("\n--- Resultados de la Consulta ---")
print(df.to_string())

print("\nGuardando los resultados en un archivo Parquet...")
df.to_csv('parquet/salidas/query_seis.csv', index=False)
print("¡Archivo 'resultados_consulta.parquet' guardado con éxito!")
# Out:
# Conectando a la base de datos y ejecutando la consulta...
#
# --- Resultados de la Consulta ---
#     cdcaso             numcuenta tptransaccion   cdpaisdestino cdparaisofiscal nivelriesgo  numoperaciones montotransacciones fhfolio
# 0  1176615  00741513380119752161      ENVIADAS           CHINA            None   RIESGO 10               2           62744.00    2023
# 1  1176615  00741513380119752161      ENVIADAS  ESTADOS UNIDOS            None    RIESGO 2               1           38500.00    2023
# 2  1185772  00744485002914964810     RECIBIDAS          MEXICO            None    RIESGO 2               1             198.16    2023
# 3  1176615  00741513380119752161      ENVIADAS           CHINA            None   RIESGO 10               6           88753.80    2024
# 4  1176615  00741513380119752161      ENVIADAS          CANADA            None    RIESGO 2               7          116998.57    2024
# 5  1176615  00741513380119752161      ENVIADAS  ESTADOS UNIDOS            None    RIESGO 2               7          135858.62    2024
# 6  1185772  00744485002914964810     RECIBIDAS          MEXICO            None    RIESGO 2               2             275.10    2024
#
# Guardando los resultados en un archivo Parquet...
# ¡Archivo 'resultados_consulta.parquet' guardado con éxito!

# %% [markdown]
# ## Consulta 9
# **Falta TSCA119_SALDOS_CTA:**
#
# La lista de casos (cdCaso) y partícipes (nbParticipesCCR) OK, pero las columnas financieras se llenarán con los valores por defecto que definimos: imSaldoCCR mostrará 0.00 imSaldoPromCCR estará vacía (nula).

# %%
mi_query9 = """
SELECT DISTINCT
    T26.CD_CASO as cdCaso,
    T26.CD_CLIENTE_PAR AS nuCtePartCCR,
    TRIM(T26.CD_INTERVENCION || ' ' || T26.NU_SECUENCIA || ' ' || CASE
        WHEN B.TP_PERSONA = 'F'
        THEN B.NB_NOMBRE || ' ' || B.NB_AP_PATERNO || ' ' || B.NB_AP_MATERNO
        ELSE B.NB_NOMBRE || B.NB_AP_PATERNO || B.NB_AP_MATERNO
    END) AS nbParticipesCCR
    -- to_char(COALESCE(C.IM_SALDO, 0),'999,999,999,999.00') AS imSaldoCCR
    -- C.IM_PROMEDIO AS imSaldoPromCCR
FROM
    TSCA026_RELCTECTA T26
LEFT JOIN TSCA016_CLIENTE B ON T26.CD_CLIENTE_PAR = B.CD_CLIENTE
-- LEFT JOIN TSCA119_SALDOS_CTA C ON substr(T26.NU_CUENTA_PAR, -10) = SUBSTR(C.CD_CUENTA_COMP, -10)
WHERE
    -- El filtro con IN se mantiene
    T26.CD_CASO IN (&CD_CASO_LIST)
    --AND substr(T26.NU_CUENTA_PAR,-10) = substr(TRIM(V_NU_CUENTA),-10)
    AND T26.CD_CLIENTE_PAR NOT IN ('&NU_CLIENTE_LIST');
"""

# %%
import re

query_in = mi_query9.replace("&CD_SISTEMA_LIST", CD_SISTEMA)\
    .replace("&CD_ALERTA_LIST", CD_ALERTA)\
    .replace("&CD_CASO_LIST", CD_CASO)\
    .replace("&NU_CLIENTE_LIST", NU_CLIENTE_LIST)

query_segura = re.sub(r'&\w+', '%s', query_in)

print("\nConectando a la base de datos y ejecutando la consulta...")
conn = psycopg2.connect(**db_connection_params)
cursor = conn.cursor()

cursor.execute(query_segura)

if cursor.rowcount == 0:
    print("\nLa consulta se ejecutó correctamente, pero no arrojó resultados.")

columnas = [desc[0] for desc in cursor.description]

registros = cursor.fetchall()

df = pd.DataFrame(registros, columns=columnas)

print("\n--- Resultados de la Consulta ---")
print(df.to_string())

print("\nGuardando los resultados en un archivo Parquet...")
df.to_csv('parquet/salidas/query_nueve.csv', index=False)
print("¡Archivo 'resultados_consulta.parquet' guardado con éxito!")
# Out:
# Conectando a la base de datos y ejecutando la consulta...
#
# --- Resultados de la Consulta ---
#      cdcaso nuctepartccr                                                  nbparticipesccr
# 0   1176615     97690262                         A 1 ARMANDO SILVESTRE CONTRERAS ANCHONDO
# 1   1176615     D1714830  T 1 SERVICIOS INDUSTRIALES E INGENIERIA CIVIL CMJ S DE RL DE CV
# 2   1180636     75816071                                 A 1 MANUEL ALFREDO CAMPAS DUARTE
# 3   1180636     75816071                                 A 2 MANUEL ALFREDO CAMPAS DUARTE
# 4   1180636     E1395002                                                             None
# 5   1180636     E1447669                                        A 1 FAUSTINO TORRES NUÑEZ
# 6   1185772     A2480820                                          U 1 PEDRO GARZA RAMIREZ
# 7   1185772     A4782243                                         T 1 ARIADNE GARZA HUGHES
# 8   1197600     D5631652   T 1 SUMINISTROS, MATERIALES,RENTA Y FLETES PARA OBRAS SA DE CV
# 9   1197600     J2018888                                     A 1 DARWIN ANGEL HERRERA MEX
# 10  1198373     98903126                                       T 1 ALEJANDRO PEREZ CORONA
# 11  1198373     98903258                                   B 1 BRENDA SARAHI PEREZ ORTEGA
# 12  1198373     98903277                                          B 2 ANDRES PEREZ ORTEGA
# 13  1198373     98903330                                       B 3 SEBASTIAN PEREZ CORTEZ
# 14  1198373     98903339                                         B 4 ROSSANA PEREZ CORTEZ
# 15  1198373     E1332464                                    T 1 JOVIBIANO SANTIAGO CARMEN
#
# Guardando los resultados en un archivo Parquet...
# ¡Archivo 'resultados_consulta.parquet' guardado con éxito!

# %% [markdown]
# ## Consulta 10
#
# No tenemos data para:
#
# - **TSCA119_SALDOS_CTA**:
#
# Se puede quitar sin problemas. De hecho, dado que su única columna seleccionada (IM_PROMEDIO) no se utiliza al final, eliminar esta tabla y su JOIN podría optimizar la consulta.
# - **TSCA101_CTE_CTA_SMD**:
#
# Se perderán las columnas de fecha de apertura y cancelación en tu reporte. Si no son cruciales se puede eliminar toda la subconsulta TCTE.
# - **TSCA062_CTO_PAT**:
#
# La lógica para calcular imLimCCR se verá afectada. Específicamente, cuando el límite de la tarjeta de crédito sea menor a 1, el resultado de imLimCCR será NULL en lugar del saldo de la cuenta patrimonial.
# - **TSCA061_CONT_TDC**:
#
# Mandaron data vacía, para todas las cuentas que no encuentren una correspondencia en TSCA061_CONT_TDC, los valores de IM_LMT_CRD y IM_DISPUESTO_TOT serán NULL. Esto provocará que los cálculos para imLimCCR y imDispCCR no se completen correctamente, resultando probablemente en valores nulos o incorrectos.

# %%
mi_query10 = """
SELECT DISTINCT
       T26.cdCaso,
       T26.cdClienteCCR,
       TO_CHAR(TCTE.fhApertura,'DD/MM/YYYY') fhAperturaCCR,
       T26.nuCuentaCCR,
       T26.nbEstatusCCR,
       T26.nbProductoCCR,       
       TCTE.st_cla_inter || ' - ' || TCTE.cd_sec_inter || ' ' || TCTE.nombre nbTitularCCR,
       TO_CHAR(TCTE.fhCancelacionCCR,'DD/MM/YYYY') fhCancelacionCCR ,
       TO_CHAR(CASE
          WHEN   CTO.im_lmt_crd <1
          THEN   CTO_PAT.im_sdo_mes_act 
          ELSE CTO.im_lmt_crd  
       END ,'999,999,999,999.00')  imLimCCR,
      TO_CHAR( CASE
          WHEN  CTO.im_lmt_crd <1
          THEN 0
          ELSE CTO.im_dispuesto_tot 
       END,'999,999,999,999.00')  imDispCCR ,
       '0' imSaldoCCR
FROM -- Subconsulta T26 (Cuentas relacionadas al caso)
     (SELECT DISTINCT               
             A.NU_CUENTA_PAR AS nuCuentaCCR,
             A.NB_BLOQUEO AS nbEstatusCCR,
             A.CD_INTERVENCION,
             A.NU_SECUENCIA,
             CASE 
                 WHEN LENGTH(C.CD_PRODUCTO || ' - ' || C.NB_PRODUCTO) > 6 THEN C.CD_PRODUCTO || ' - ' || C.NB_PRODUCTO
                 ELSE 'NO EXISTE PRODUCTO EN CATALOGO ' 
             END AS nbProductoCCR,               
             A.CD_CASO AS cdCaso,
             A.CD_CLIENTE_PAR AS cdClienteCCR
      FROM TSCA026_RELCTECTA A
      LEFT JOIN TSCA071_PRD_SBPRD C ON
            CAST(
                CASE
                    WHEN LENGTH(TRIM(A.NU_CUENTA_PAR)) > 10 THEN SUBSTR(A.NU_CUENTA_PAR, 11, 2)
                    ELSE SUBSTR(A.NU_CUENTA_PAR, 1, 2)
                END 
            AS INTEGER) = C.CD_PRODUCTO
      -- CAMBIO: Se usa IN para una lista de casos
      WHERE A.CD_CASO IN (&CD_CASO_LIST)
        AND A.CD_CLIENTE_PAR = (SELECT DISTINCT CD_CLIENTE FROM TSCA014_CASO WHERE CD_CASO = A.CD_CASO)
        AND CASE
                WHEN LENGTH(TRIM(A.NU_CUENTA_PAR)) > 10 THEN SUBSTR(A.NU_CUENTA_PAR, 11, 2)
                ELSE SUBSTR(A.NU_CUENTA_PAR, 1, 2)
            END NOT IN ('01', '04', '11', '12', '14', '26', '27', '28', '29')
     ) T26
LEFT JOIN -- Subconsulta TCTE (Datos del cliente/titular)
     (SELECT A.st_cla_inter,
             A.cd_sec_inter,
             A.nu_cuenta,
             CASE
                WHEN B.TP_PERSONA = 'F' THEN B.NB_NOMBRE || ' ' || B.NB_AP_PATERNO || ' ' || B.NB_AP_MATERNO
                ELSE B.NB_NOMBRE || B.NB_AP_PATERNO || B.NB_AP_MATERNO
             END AS nombre,
             B.CD_CASO,
             A.fhCancelacion AS fhCancelacionCCR,
             A.fhApertura,
             A.cd_cliente
      FROM TSCA016_CLIENTE B
      LEFT JOIN 
           (SELECT A.CD_CLIENTE,
                   A.ST_CLA_INTER,
                   A.CD_SEC_INTER,
                   A.NU_CUENTA,
                   CASE WHEN A.ST_CTA IS NULL THEN NULL ELSE A.FH_CANCELACION END AS fhCancelacion,
                   CASE WHEN TO_CHAR(FH_APERTURA_CTA,'DD/MM/YYYY') = '01/01/0001' THEN FH_ALTA_RELA_CTA ELSE FH_APERTURA_CTA END AS fhApertura
            FROM TSCA101_CTE_CTA_SMD A
           ) A ON B.CD_CLIENTE = A.CD_CLIENTE
      -- CAMBIO: Se usa IN para una lista de casos
      WHERE B.CD_CASO IN (&CD_CASO_LIST)
     ) TCTE ON substr(T26.nuCuentaCCR, -10) = substr(TCTE.nu_cuenta, -10) AND T26.cdClienteCCR = TCTE.cd_cliente
LEFT JOIN -- Subconsulta CTO (Límite de crédito)
     (SELECT DISTINCT T61.IM_LMT_CRD AS im_lmt_crd, T61.IM_DISPUESTO_TOT AS im_dispuesto_tot, T61.CD_CONTRATO
      FROM TSCA061_CONT_TDC T61
      -- CAMBIO: Se usa IN para una lista de casos
      WHERE T61.CD_CASO IN (&CD_CASO_LIST)
     ) CTO ON substr(T26.nuCuentaCCR, -10) = substr(CTO.CD_CONTRATO, -10)
LEFT JOIN -- Subconsulta CTO_PAT (Saldo patrimonial)
     (SELECT T62.IM_SDO_MES_ACT AS im_sdo_mes_act, T62.CD_CONTRATO_MUV
      FROM TSCA062_CTO_PAT T62
      -- CAMBIO: Se usa IN para una lista de casos
      WHERE T62.CD_CASO IN (&CD_CASO_LIST)
        -- CAMBIO: Se usa IN también en la subconsulta para consistencia
        AND T62.FH_PROCESO = (SELECT MAX(FH_PROCESO) FROM TSCA062_CTO_PAT WHERE CD_CASO IN (&CD_CASO_LIST))
     ) CTO_PAT ON substr(T26.nuCuentaCCR, -10) = substr(CTO_PAT.CD_CONTRATO_MUV, -10);
"""

# %%
import re

query_in = mi_query10.replace("&CD_SISTEMA_LIST", CD_SISTEMA)\
    .replace("&CD_ALERTA_LIST", CD_ALERTA)\
    .replace("&CD_CASO_LIST", CD_CASO)

query_segura = re.sub(r'&\w+', '%s', query_in)

print("\nConectando a la base de datos y ejecutando la consulta...")
conn = psycopg2.connect(**db_connection_params)
cursor = conn.cursor()

cursor.execute(query_segura)

if cursor.rowcount == 0:
    print("\nLa consulta se ejecutó correctamente, pero no arrojó resultados.")

columnas = [desc[0] for desc in cursor.description]

registros = cursor.fetchall()

df = pd.DataFrame(registros, columns=columnas)

print("\n--- Resultados de la Consulta ---")
print(df.to_string())

print("\nGuardando los resultados en un archivo Parquet...")
df.to_csv('parquet/salidas/query_diez.csv', index=False)
print("¡Archivo 'resultados_consulta.parquet' guardado con éxito!")
# Out:
# Conectando a la base de datos y ejecutando la consulta...
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# Cell In[8], line 13
#      10 conn = psycopg2.connect(**db_connection_params)
#      11 cursor = conn.cursor()
# ---> 13 cursor.execute(query_segura)
#      15 if cursor.rowcount == 0:
#      16     print("\nLa consulta se ejecutó correctamente, pero no arrojó resultados.")
#
# UndefinedTable: relation "tsca061_cont_tdc" does not exist
# LINE 77:       FROM TSCA061_CONT_TDC T61
#                     ^

# %% [markdown]
# ## Consulta 8

# %%
mi_query8 = """
SELECT DISTINCT
      T26.cdCaso,
      T26.cdClienteCCR,
      CASE WHEN T26.FH_APERTURA IS NULL THEN TO_CHAR(TCTE.FH_APERTURA_CTA,'DD/MM/YYYY') ELSE TO_CHAR(T26.FH_APERTURA,'DD/MM/YYYY') END fhAperturaCCR,
      T26.nuCuentaCCR,
      T26.nbEstatusCCR,
      T26.nbProductoCCR,
      T26.CD_SUBPRODUCTO || ' - ' || T71.NB_SUBPRODUCTO nbSubproductoCCR,
      TCTE.ST_CLA_INTER || ' - ' || TCTE.CD_SEC_INTER || ' ' || TCTE.NOMBRE nbTitularCCR,
      TO_CHAR(TCTE.FH_CANCELACION,'DD/MM/YYYY') fhCancelacionCCR,
      '0' imSaldoCCR
FROM -- Subconsulta principal T26
    (SELECT DISTINCT
            B.IM_SALDO,
            B.FH_APERTURA,
            A.NU_CUENTA_PAR AS nuCuentaCCR,
            A.NB_BLOQUEO AS nbEstatusCCR,
            A.CD_INTERVENCION,
            A.NU_SECUENCIA,
            (SELECT DISTINCT CD_PRODUCTO || ' - ' || NB_PRODUCTO FROM TSCA071_PRD_SBPRD WHERE CD_PRODUCTO = CAST(CASE WHEN LENGTH (A.NU_CUENTA_PAR) > 10 THEN SUBSTR (A.NU_CUENTA_PAR, 11, 2) ELSE SUBSTR (A.NU_CUENTA_PAR, 1, 2) END AS INTEGER)) AS nbProductoCCR,
            B.CD_SUBPRODUCTO,
            A.CD_CASO AS cdCaso,
            A.CD_CLIENTE_PAR AS cdClienteCCR,
            B.TP_CARGA,
            CASE WHEN LENGTH (A.NU_CUENTA_PAR) > 10 THEN SUBSTR (A.NU_CUENTA_PAR, 11, 2) ELSE SUBSTR (A.NU_CUENTA_PAR, 1, 2) END AS PROD_A
    FROM
            TSCA026_RELCTECTA A 
            LEFT JOIN TSCA119_SALDOS_CTA B ON SUBSTR(A.NU_CUENTA_PAR,-10) = SUBSTR(B.CD_CUENTA_COMP,-10) AND A.CD_CASO = CAST(B.CD_CASO AS INTEGER)
    WHERE
            A.CD_CASO IN (&CD_CASO_LIST)
            AND A.CD_CLIENTE_PAR = (SELECT DISTINCT CD_CLIENTE FROM TSCA014_CASO WHERE CD_CASO = A.CD_CASO)
            -- CAMBIO: Se eliminan los TRIM de las condiciones
            AND CASE WHEN LENGTH (A.NU_CUENTA_PAR) > 10 THEN SUBSTR (A.NU_CUENTA_PAR, 11, 2) ELSE SUBSTR (A.NU_CUENTA_PAR, 1, 2) END IN ('01', '04', '11', '12', '14', '26', '27', '28', '29')
    ) T26
-- CAMBIO: Se corrige la sintaxis del CAST
LEFT JOIN TSCA071_PRD_SBPRD T71 
    ON CAST(T26.PROD_A AS INTEGER) = T71.CD_PRODUCTO AND CAST(T26.CD_SUBPRODUCTO AS INTEGER) = CAST(T71.CD_SUBPRODUCTO AS INTEGER)
LEFT JOIN -- Subconsulta TCTE para datos del titular
    (SELECT
            A.ST_CLA_INTER,
            A.CD_SEC_INTER,
            A.NU_CUENTA,
            CASE WHEN B.TP_PERSONA = 'F' THEN B.NB_NOMBRE || ' ' || B.NB_AP_PATERNO || ' ' || B.NB_AP_MATERNO ELSE B.NB_NOMBRE || B.NB_AP_PATERNO || B.NB_AP_MATERNO END AS NOMBRE,
            B.CD_CASO,
            A.FH_CANCELACION,
            A.CD_CLIENTE,
            A.FH_APERTURA_CTA
    FROM 
            TSCA016_CLIENTE B
            LEFT JOIN (
                  SELECT
                    A.CD_CLIENTE,
                    A.ST_CLA_INTER,
                    A.CD_SEC_INTER,
                    A.NU_CUENTA,
                    CASE WHEN A.ST_CTA IS NULL THEN NULL ELSE A.FH_CANCELACION END AS FH_CANCELACION,
                    CASE WHEN TO_CHAR(FH_APERTURA_CTA,'DD/MM/YYYY') = '01/01/0001' THEN FH_ALTA_RELA_CTA ELSE FH_APERTURA_CTA END AS FH_APERTURA_CTA
                  FROM
                    TSCA101_CTE_CTA_SMD A
            ) A ON B.CD_CLIENTE = A.CD_CLIENTE
    WHERE
            B.CD_CASO IN (&CD_CASO_LIST)
    ) TCTE 
    ON SUBSTR (T26.nuCuentaCCR,-10) = TCTE.NU_CUENTA AND T26.cdClienteCCR = TCTE.CD_CLIENTE
WHERE
    (T26.TP_CARGA IS NULL OR T26.TP_CARGA = 'A');
"""

# %%
import re

query_in = mi_query8.replace("&CD_SISTEMA_LIST", CD_SISTEMA)\
    .replace("&CD_ALERTA_LIST", CD_ALERTA)\
    .replace("&CD_CASO_LIST", CD_CASO)

query_segura = re.sub(r'&\w+', '%s', query_in)

print("\nConectando a la base de datos y ejecutando la consulta...")
conn = psycopg2.connect(**db_connection_params)
cursor = conn.cursor()

cursor.execute(query_segura)

if cursor.rowcount == 0:
    print("\nLa consulta se ejecutó correctamente, pero no arrojó resultados.")

columnas = [desc[0] for desc in cursor.description]

registros = cursor.fetchall()

df = pd.DataFrame(registros, columns=columnas)

print("\n--- Resultados de la Consulta ---")
print(df.to_string())

print("\nGuardando los resultados en un archivo Parquet...")
df.to_csv('parquet/salidas/query_ocho.csv', index=False)
print("¡Archivo 'resultados_consulta.parquet' guardado con éxito!")
# Out:
# Conectando a la base de datos y ejecutando la consulta...
#
# --- Resultados de la Consulta ---
#      cdcaso cdclienteccr fhaperturaccr           nucuentaccr   nbestatusccr          nbproductoccr nbsubproductoccr nbtitularccr fhcancelacionccr imsaldoccr
# 0   1176615     D1714830          None  00741513000118876274  CUENTA ACTIVA  1 - CUENTA DE CHEQUES             None         None             None          0
# 1   1176615     D1714830          None  00741513000119752161  CUENTA ACTIVA  1 - CUENTA DE CHEQUES             None         None             None          0
# 2   1180636     E1395002          None  00747696000124019830  CUENTA ACTIVA  1 - CUENTA DE CHEQUES             None         None             None          0
# 3   1180636     E1395002          None  00747696000124019946  CUENTA ACTIVA  1 - CUENTA DE CHEQUES             None         None             None          0
# 4   1180636     E1395002          None  00747696000124019989  CUENTA ACTIVA  1 - CUENTA DE CHEQUES             None         None             None          0
# 5   1180636     E1395002          None  00747696000124029283  CUENTA ACTIVA  1 - CUENTA DE CHEQUES             None         None             None          0
# 6   1180636     E1395002          None  00747696000124275780  CUENTA ACTIVA  1 - CUENTA DE CHEQUES             None         None             None          0
# 7   1180636     E1395002          None  00747696000124275810  CUENTA ACTIVA  1 - CUENTA DE CHEQUES             None         None             None          0
# 8   1180636     E1395002          None  00747696000124275845  CUENTA ACTIVA  1 - CUENTA DE CHEQUES             None         None             None          0
# 9   1180636     E1395002          None  00747696000124275888  CUENTA ACTIVA  1 - CUENTA DE CHEQUES             None         None             None          0
# 10  1180636     E1395002          None  00747696000124386906  CUENTA ACTIVA  1 - CUENTA DE CHEQUES             None         None             None          0
# 11  1180636     E1395002          None  00747696000124386957  CUENTA ACTIVA  1 - CUENTA DE CHEQUES             None         None             None          0
# 12  1180636     E1395002          None  00747696000124386981  CUENTA ACTIVA  1 - CUENTA DE CHEQUES             None         None             None          0
# 13  1180636     E1395002          None  00747696000124387201  CUENTA ACTIVA  1 - CUENTA DE CHEQUES             None         None             None          0
# 14  1180636     E1395002          None  00747696000124387317  CUENTA ACTIVA  1 - CUENTA DE CHEQUES             None         None             None          0
# 15  1185772     A4782243          None  00744485002914964810  CUENTA ACTIVA            29 - AHORRO             None         None             None          0
# 16  1197600     D5631652          None  00745765000120584754  CUENTA ACTIVA  1 - CUENTA DE CHEQUES             None         None             None          0
#
# Guardando los resultados en un archivo Parquet...
# ¡Archivo 'resultados_consulta.parquet' guardado con éxito!

# %%
kirby {
    input {
        options {
            includeMetadataAndDeleted = true
            overrideSchema = true
        }
        tables = [
            "mx_master.t_mceg_community_prosp"
        ]
        type="table"
    }
    output {
        coalesce {
            partitions=${?KIRBY_REPARTITION}
        }
        force=true
        mode="overwrite"
        partition=[
            "cutoff_date"
        ]
        dropLeftoverFields = true
        options {
            partitionOverwriteMode = "dynamic"
        }
        table = "mx_master.t_mceg_community_prosp_l1t"
        compact = true
        compactConfig {
            forceTargetPathRemove = true
            report = true
            partitionsFilter = "cutoff_date ='"${?DATE}"'"
        }
        type="table"
    }
    transformations=[
        {
            filter = "cutoff_date ='"${?DATE}"'"
            type=sqlFilter
        }
    ]
}
